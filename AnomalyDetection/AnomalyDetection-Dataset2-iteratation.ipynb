# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
import ast

# %% [markdown]
# ### Loading the dataset

# %%
expenditures_df = pd.read_csv('../SavedData/dataset2_expenditures.csv')
payments_df= pd.read_csv('../SavedData/dataset2_payments.csv')
expenditures_users_df = pd.read_csv('../SavedData/dataset2_expenditures_by_users.csv')
payments_users_df = pd.read_csv('../SavedData/dataset2_payments_by_users.csv')
simulated_cleaned_tx_df = pd.read_csv('../SavedData/dataset2_cleaned.csv')

# %%
simulated_cleaned_tx_df
# Out:
#               Date Timestamp   Account No       Balance   Amount  \
# 0       01/01/2023  00:00:00  678330503.0   2971.000000  1584.00
# 1       01/01/2023  00:00:00  472213568.0   3792.000000  1950.00
# 2       01/01/2023  00:00:00  472213568.0   3012.000000  -780.00
# 3       01/01/2023  00:00:00  283027736.0   1787.000000   780.00
# 4       01/01/2023  00:00:00  624500124.0   3226.000000  1825.00
# ...            ...       ...          ...           ...      ...
# 229189  06/12/2023  20:54:00  581655972.0  45935.206861   -41.06
# 229190  06/12/2023  20:55:00  786141370.0   -244.837500   -62.35
# 229191  06/12/2023  21:05:00  824916823.0   9709.172159   -32.94
# 229192  06/12/2023  21:13:00  366550080.0  26834.165794   -19.25
# 229193  06/12/2023  21:32:00  259015404.0   1145.349837   -37.64
#
#         Third Party Account No    Third Party Name             Datetime
# 0                          NaN  Westport Care Home  2023-01-01 00:00:00
# 1                          NaN    Barbiee Boutique  2023-01-01 00:00:00
# 2                  283027736.0                 NaN  2023-01-01 00:00:00
# 3                  472213568.0                 NaN  2023-01-01 00:00:00
# 4                          NaN            Fat Face  2023-01-01 00:00:00
# ...                        ...                 ...                  ...
# 229189                     NaN               Tesco  2023-12-06 20:54:00
# 229190                     NaN     Sainsbury Local  2023-12-06 20:55:00
# 229191                     NaN           Deliveroo  2023-12-06 21:05:00
# 229192                     NaN              Amazon  2023-12-06 21:13:00
# 229193                     NaN             JustEat  2023-12-06 21:32:00
#
# [229194 rows x 8 columns]

# %%
expenditures_users_df
# Out:
#       Account No  total_transactions  total_spent  median_transaction  \
# 0    101531259.0                 110     17627.58              88.580
# 1    104832000.0                 150     25115.52              49.920
# 2    105375973.0                 146     10067.28              48.160
# 3    106601471.0                 180      7760.01              19.965
# 4    108481285.0                 344     15062.28              21.510
# ..           ...                 ...          ...                 ...
# 971  995615876.0                 172     17598.80              52.920
# 972  996042490.0                 243     35268.01              34.970
# 973  998390769.0                 140     21323.35              69.990
# 974  998405607.0                 145      8816.16              35.070
# 975  999752672.0                 315     30464.72              17.910
#
#      mean_transaction                              business_interactions  \
# 0          160.250727  ['LBG', 'Disney', 'Grand Union BJJ', 'Matalan'...
# 1          167.436800  ['LBG', 'Netflix', 'Grand Union BJJ', 'Blizzar...
# 2           68.953973  ['PureGym', 'Netflix', 'Amazon', "Blackwell's"...
# 3           43.111167  ['Mojang Studios', 'Netflix', 'The Crown', "Bl...
# 4           43.785698  ['Disney', 'Amazon', 'PureGym', "Blackwell's",...
# ..                ...                                                ...
# 971        102.318605  ['LBG', 'Blizzard', 'Mojang Studios', 'The Cro...
# 972        145.135844  ['Halifax', 'Netflix', 'PureGym', "Blackwell's...
# 973        152.309643  ['Halifax', 'Disney', 'Netflix', 'Mojang Studi...
# 974         60.801103  ['Xbox', 'Blizzard', 'Mojang Studios', 'Netfli...
# 975         96.713397  ['Halifax', 'Netflix', 'The Works', 'Coffee #1...
#
#     user_interactions most_recent_transaction
# 0                  []              2023-12-05
# 1       [587923845.0]              2023-12-03
# 2                  []              2023-12-03
# 3                  []              2023-12-06
# 4       [913801979.0]              2023-12-06
# ..                ...                     ...
# 971                []              2023-12-05
# 972     [792845450.0]              2023-12-06
# 973                []              2023-12-01
# 974                []              2023-11-30
# 975     [211493028.0]              2023-12-05
#
# [976 rows x 8 columns]

# %% [markdown]
# ### Splitting the data into training and testing

# %%
copied_simulated_tx_df = simulated_cleaned_tx_df.copy()

# Splitting the copied dataset into historical_transactions (95%) and testing_transactions (5%)
training_transactions, testing_transactions = train_test_split(copied_simulated_tx_df, test_size=0.1, random_state=12)

# Displaying the shapes to verify the split
training_transactions.shape, testing_transactions.shape
# Out:
# ((206274, 8), (22920, 8))

# %%
testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
# [22920 rows x 8 columns]

# %% [markdown]
# ### Splitting the training transactions into payments and expenditures

# %%
payments_training_df = training_transactions[training_transactions['Amount'] > 0]
expenditures_training_df = training_transactions[training_transactions['Amount'] < 0]

# %%
# Taking the absolute values of the amount column
expenditures_training_df["Amount"] = expenditures_training_df["Amount"].abs()

expenditures_training_df
# Out:
# /var/folders/rw/215myrns4md_n1k8nkyww6mw0000gn/T/ipykernel_40022/721076894.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expenditures_training_df["Amount"] = expenditures_training_df["Amount"].abs()
#               Date Timestamp   Account No       Balance  Amount  \
# 215690  22/11/2023  18:12:00  496674181.0  -2187.525472  111.38
# 20958   31/01/2023  10:05:00  421881811.0   2363.284100   22.00
# 197261  30/10/2023  20:06:00  387957305.0  -2677.341106   37.99
# 63359   03/04/2023  08:51:00  120634201.0   1441.908700   41.04
# 6331    02/01/2023  18:47:00  713910252.0   2116.752100  140.49
# ...            ...       ...          ...           ...     ...
# 206083  05/11/2023  07:55:00  550169791.0  22875.430900   45.04
# 36482   23/02/2023  12:38:00  554792076.0   2248.810443   75.74
# 40177   01/03/2023  00:00:00  624563756.0    -14.727071  822.00
# 150781  24/08/2023  20:15:00  176922958.0   1440.312330   37.43
# 210763  13/11/2023  10:23:00  749378808.0   4130.408178  138.56
#
#         Third Party Account No Third Party Name             Datetime
# 215690                     NaN       Coop Local  2023-11-22 18:12:00
# 20958                      NaN    Sports Direct  2023-01-31 10:05:00
# 197261                     NaN            Tesco  2023-10-30 20:06:00
# 63359                      NaN            Tesco  2023-04-03 08:51:00
# 6331                       NaN            Tesco  2023-01-02 18:47:00
# ...                        ...              ...                  ...
# 206083                     NaN             Etsy  2023-11-05 07:55:00
# 36482                      NaN          Topshop  2023-02-23 12:38:00
# 40177                      NaN              LBG  2023-03-01 00:00:00
# 150781                     NaN        Deliveroo  2023-08-24 20:15:00
# 210763                     NaN         Fat Face  2023-11-13 10:23:00
#
# [196934 rows x 8 columns]

# %% [markdown]
# ### Feature engineering for anomaly detection: expenditure

# %%
# Calculating Q1, Q3, and IQR for each account in 'from_totally_fake_account'
quartiles = expenditures_training_df.groupby('Account No')['Amount'].quantile([0.25, 0.5, 0.75]).unstack()
quartiles['IQR'] = quartiles[0.75] - quartiles[0.25]

thresholds = quartiles.copy()
thresholds['Overall_Threshold_1_IQR'] = quartiles[0.75] + 1.5 * quartiles['IQR']
thresholds['Overall_Threshold_2_IQR'] = quartiles[0.75] + 3 * quartiles['IQR']
thresholds['Overall_Threshold_3_IQR'] = quartiles[0.75] + 5 * quartiles['IQR']

anomaly_detection_by_expenditures_df = thresholds


anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
# [976 rows x 7 columns]

# %% [markdown]
# ### Creating thresholds for each user to user transfers

# %%
# Threshold function
def calculate_thresholds(group, multiplier):
#     if len(group) <= 1:  # Check if there's only one expenditure
#         return np.nan  # Indicative value for groups with only one transaction
    quantiles = group['Amount'].quantile([0.25, 0.75])
    IQR = quantiles[0.75] - quantiles[0.25]
    threshold = quantiles[0.75] + multiplier * IQR
    return threshold

# %%
# Applying the adjusted function for each threshold calculation with different multipliers

# For Threshold 1 (1.5 * IQR)
thresholds_1 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 1.5)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_1']))).to_dict()

# For Threshold 2 (3 * IQR)
thresholds_2 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_2']))).to_dict()

# For Threshold 3 (5 * IQR)
thresholds_3 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 5)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_3']))).to_dict()

anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_1'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_2'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_3'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 670.0}            {587923845.0: 670.0}
# 105375973.0                             NaN                             NaN
# 106601471.0                             NaN                             NaN
# 108481285.0           {913801979.0: 2185.0}           {913801979.0: 2552.5}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0           {792845450.0: 1500.0}           {792845450.0: 1500.0}
# 998390769.0                             NaN                             NaN
# 998405607.0                             NaN                             NaN
# 999752672.0            {211493028.0: 680.0}            {211493028.0: 680.0}
#
#             Third_Party_Account_Threshold_3
# Account No
# 101531259.0                             NaN
# 104832000.0            {587923845.0: 670.0}
# 105375973.0                             NaN
# 106601471.0                             NaN
# 108481285.0           {913801979.0: 3042.5}
# ...                                     ...
# 995615876.0                             NaN
# 996042490.0           {792845450.0: 1500.0}
# 998390769.0                             NaN
# 998405607.0                             NaN
# 999752672.0            {211493028.0: 680.0}
#
# [976 rows x 10 columns]

# %% [markdown]
# ### Creating thresholds for each user to business transactions

# %%
# For Threshold 1 (1.5 * IQR)
thresholds_1 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 1.5)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_1']))).to_dict()

# For Threshold 2 (3 * IQR)
thresholds_2 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_2']))).to_dict()

# For Threshold 3 (5 * IQR)
thresholds_3 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 5)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_3']))).to_dict()

anomaly_detection_by_expenditures_df['Business_Threshold_1'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_df['Business_Threshold_2'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_df['Business_Threshold_3'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 670.0}            {587923845.0: 670.0}
# 105375973.0                             NaN                             NaN
# 106601471.0                             NaN                             NaN
# 108481285.0           {913801979.0: 2185.0}           {913801979.0: 2552.5}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0           {792845450.0: 1500.0}           {792845450.0: 1500.0}
# 998390769.0                             NaN                             NaN
# 998405607.0                             NaN                             NaN
# 999752672.0            {211493028.0: 680.0}            {211493028.0: 680.0}
#
#             Third_Party_Account_Threshold_3  \
# Account No
# 101531259.0                             NaN
# 104832000.0            {587923845.0: 670.0}
# 105375973.0                             NaN
# 106601471.0                             NaN
# 108481285.0           {913801979.0: 3042.5}
# ...                                     ...
# 995615876.0                             NaN
# 996042490.0           {792845450.0: 1500.0}
# 998390769.0                             NaN
# 998405607.0                             NaN
# 999752672.0            {211493028.0: 680.0}
#
#                                           Business_Threshold_1  \
# Account No
# 101531259.0  {'Brilliant Brushes': 85.97999999999999, 'Deli...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.1950000000000003, 'Amazon': 102.7...
# 108481285.0  {'AMAZON': 38.41, 'Amazon': 35.025000000000006...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 33.9574999999...
# 996042490.0  {'Blackwell's': 41.94, 'Blizzard': 14.99, 'Boo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 8.14999999999999...
#
#                                           Business_Threshold_2  \
# Account No
# 101531259.0  {'Brilliant Brushes': 124.97999999999999, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.2475000000000005, 'Amazon': 145.3...
# 108481285.0  {'AMAZON': 53.8, 'Amazon': 51.27000000000001, ...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.37, 'Fat F...
# 996042490.0  {'Blackwell's': 50.925, 'Blizzard': 14.99, 'Bo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 9.79999999999999...
#
#                                           Business_Threshold_3
# Account No
# 101531259.0  {'Brilliant Brushes': 176.97999999999996, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.317500000000001, 'Amazon': 202.13...
# 108481285.0  {'AMAZON': 74.32, 'Amazon': 72.93, 'Blackwell'...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.9199999999...
# 996042490.0  {'Blackwell's': 62.90499999999999, 'Blizzard':...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 11.9999999999999...
#
# [976 rows x 13 columns]

# %%
# Extracting keys from 'transfer_to_accounts_threshold_1_IQR' to create 'user_user_interaction'
anomaly_detection_by_expenditures_df['user_user_interaction'] = anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# Extracting keys from 'industry_threshold_1_IQR' to create 'user_industry_interaction'
anomaly_detection_by_expenditures_df['user_business_interaction'] = anomaly_detection_by_expenditures_df['Business_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 670.0}            {587923845.0: 670.0}
# 105375973.0                             NaN                             NaN
# 106601471.0                             NaN                             NaN
# 108481285.0           {913801979.0: 2185.0}           {913801979.0: 2552.5}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0           {792845450.0: 1500.0}           {792845450.0: 1500.0}
# 998390769.0                             NaN                             NaN
# 998405607.0                             NaN                             NaN
# 999752672.0            {211493028.0: 680.0}            {211493028.0: 680.0}
#
#             Third_Party_Account_Threshold_3  \
# Account No
# 101531259.0                             NaN
# 104832000.0            {587923845.0: 670.0}
# 105375973.0                             NaN
# 106601471.0                             NaN
# 108481285.0           {913801979.0: 3042.5}
# ...                                     ...
# 995615876.0                             NaN
# 996042490.0           {792845450.0: 1500.0}
# 998390769.0                             NaN
# 998405607.0                             NaN
# 999752672.0            {211493028.0: 680.0}
#
#                                           Business_Threshold_1  \
# Account No
# 101531259.0  {'Brilliant Brushes': 85.97999999999999, 'Deli...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.1950000000000003, 'Amazon': 102.7...
# 108481285.0  {'AMAZON': 38.41, 'Amazon': 35.025000000000006...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 33.9574999999...
# 996042490.0  {'Blackwell's': 41.94, 'Blizzard': 14.99, 'Boo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 8.14999999999999...
#
#                                           Business_Threshold_2  \
# Account No
# 101531259.0  {'Brilliant Brushes': 124.97999999999999, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.2475000000000005, 'Amazon': 145.3...
# 108481285.0  {'AMAZON': 53.8, 'Amazon': 51.27000000000001, ...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.37, 'Fat F...
# 996042490.0  {'Blackwell's': 50.925, 'Blizzard': 14.99, 'Bo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 9.79999999999999...
#
#                                           Business_Threshold_3  \
# Account No
# 101531259.0  {'Brilliant Brushes': 176.97999999999996, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.317500000000001, 'Amazon': 202.13...
# 108481285.0  {'AMAZON': 74.32, 'Amazon': 72.93, 'Blackwell'...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.9199999999...
# 996042490.0  {'Blackwell's': 62.90499999999999, 'Blizzard':...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 11.9999999999999...
#
#             user_user_interaction  \
# Account No
# 101531259.0                  None
# 104832000.0         [587923845.0]
# 105375973.0                  None
# 106601471.0                  None
# 108481285.0         [913801979.0]
# ...                           ...
# 995615876.0                  None
# 996042490.0         [792845450.0]
# 998390769.0                  None
# 998405607.0                  None
# 999752672.0         [211493028.0]
#
#                                      user_business_interaction
# Account No
# 101531259.0  [Brilliant Brushes, Deliveroo, Disney, Fat Fac...
# 104832000.0  [A Cut Above, Blizzard, Boots, Deliveroo, Etsy...
# 105375973.0  [AMAZON, Amazon, Blackwell's, Coop Local, Deli...
# 106601471.0  [AMAZON, Amazon, Blackwell's, Blizzard, Boots,...
# 108481285.0  [AMAZON, Amazon, Blackwell's, Boots, Brilliant...
# ...                                                        ...
# 995615876.0  [Blizzard, Deliveroo, Fat Face, Gamestation, J...
# 996042490.0  [Blackwell's, Blizzard, Boots, Brilliant Brush...
# 998390769.0  [Amazon, Blizzard, Deliveroo, Disney, Fat Face...
# 998405607.0  [Blackwell's, Blizzard, Deliveroo, Fat Face, F...
# 999752672.0  [AMAZON, Coffee #1, Coop Local, Deliveroo, Ets...
#
# [976 rows x 15 columns]

# %% [markdown]
# ## Risk flagging function- per user transaction

# %%
testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
# [22920 rows x 8 columns]

# %%
def get_threshold_value(user_data, key, business=None):
    value = user_data.get(key, 0)
    if isinstance(value, dict):
        return value.get(business, float('inf'))

def assess_transaction_risk(account_no, amount, third_party_account_no, third_party_name, anomaly_detection_df):
    if amount >= 0:  # Skip payments
        return "Not Applicable"
    
    # Convert the amount to positive for comparison
    amount = abs(amount)
    risk_level = "No Risk"
    user_data = anomaly_detection_df.loc[account_no].to_dict()

    
    # Initialise interactions as empty lists to ensure they're iterable
    user_user_interaction = user_data.get('user_user_interaction', []) or []
    user_business_interaction = user_data.get('user_business_interaction', []) or []
    
    # Check if third_party_account_no is not None and is in user_user_interaction
    if third_party_account_no and third_party_account_no in user_user_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_1', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_2', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_3', third_party_account_no)
        ]
    # Check if industry_category is determined and in user_industry_interaction
    elif third_party_name and third_party_name in user_business_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Business_Threshold_1', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_2', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_3', third_party_name)
        ]
    else:
        # Use general thresholds if no specific interaction is found
        thresholds = [user_data['Overall_Threshold_1_IQR'], user_data['Overall_Threshold_2_IQR'], user_data['Overall_Threshold_3_IQR']]
    
    low_risk_floor = 15
    medium_risk_floor = 50
    high_risk_floor = 100
    
    if amount > thresholds[2]:
        risk_level = "High Risk"
    elif amount > thresholds[1]:
        risk_level = "Medium Risk"
    elif amount > thresholds[0]:
        risk_level = "Low Risk"
    
    # Adjusting risk level based on the floor values
    if risk_level == "Low Risk" and amount <= low_risk_floor:
        risk_level = "No Risk"
    elif risk_level == "Medium Risk" and amount <= low_risk_floor:
        risk_level = "No Risk"
    elif risk_level == "High Risk" and amount <= low_risk_floor:
        risk_level = "No Risk"
    elif risk_level == "Medium Risk" and amount <= medium_risk_floor:
        risk_level = "Low Risk"
    elif risk_level == "High Risk" and amount <= medium_risk_floor:
        risk_level = "Low Risk"
    elif risk_level == "High Risk" and amount <= high_risk_floor:
        risk_level = "Medium Risk"
    
    return risk_level

risk_levels = [
    assess_transaction_risk(
        row['Account No'], row['Amount'], row.get('Third Party Account No'), row['Third Party Name'],
        anomaly_detection_by_expenditures_df
    ) for index, row in testing_transactions.iterrows()
]

testing_transactions['risk_level'] = risk_levels


testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime  \
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
#        risk_level
# 50365     No Risk
# 50317     No Risk
# 156768    No Risk
# 198076    No Risk
# 46751     No Risk
# ...           ...
# 146741    No Risk
# 99244     No Risk
# 165435    No Risk
# 125773    No Risk
# 203041    No Risk
#
# [22920 rows x 9 columns]

# %%
risk_level_counts = testing_transactions['risk_level'].value_counts()
print(risk_level_counts)
# Out:
# No Risk           20880
# Not Applicable     1045
# Low Risk            660
# Medium Risk         230
# High Risk           105
# Name: risk_level, dtype: int64

# %%
# Filter for Low Risk transactions
low_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'Low Risk']

# Filter for Medium Risk transactions
medium_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'Medium Risk']

# Filter for High Risk transactions
high_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'High Risk']

# Filter for Not Applicable transactions
not_applicable_transactions = testing_transactions[testing_transactions['risk_level'] == 'Not Applicable']

# %%
low_risk_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 141449  06/08/2023  03:33:00  496395938.0  11089.827658  -88.40
# 175960  30/09/2023  10:48:00  930277104.0  11141.312949 -235.20
# 145302  13/08/2023  12:17:00  541639148.0   4904.981751 -130.89
# 124005  12/07/2023  06:01:00  128033695.0   4233.570223  -25.98
# 207582  07/11/2023  17:50:00  419550103.0  19447.397141 -114.08
# ...            ...       ...          ...           ...     ...
# 9457    08/01/2023  15:12:00  424927189.0   1595.692850 -158.50
# 52483   20/03/2023  12:30:00  355733816.0   2150.158104  -25.20
# 37637   26/02/2023  13:05:00  532525712.0     11.868100  -35.45
# 62729   02/04/2023  04:54:00  752362502.0   5349.850350  -34.14
# 99105   02/06/2023  03:26:00  537487133.0    -18.794650  -40.80
#
#         Third Party Account No Third Party Name             Datetime  \
# 141449                     NaN   Loosely Fitted  2023-08-06 03:33:00
# 175960                     NaN         Fat Face  2023-09-30 10:48:00
# 145302                     NaN         Fat Face  2023-08-13 12:17:00
# 124005                     NaN  Sainsbury Local  2023-07-12 06:01:00
# 207582                     NaN    Sports Direct  2023-11-07 17:50:00
# ...                        ...              ...                  ...
# 9457                       NaN          Topshop  2023-01-08 15:12:00
# 52483                      NaN          JustEat  2023-03-20 12:30:00
# 37637                      NaN          JustEat  2023-02-26 13:05:00
# 62729                      NaN        Deliveroo  2023-04-02 04:54:00
# 99105                      NaN        Deliveroo  2023-06-02 03:26:00
#
#        risk_level
# 141449   Low Risk
# 175960   Low Risk
# 145302   Low Risk
# 124005   Low Risk
# 207582   Low Risk
# ...           ...
# 9457     Low Risk
# 52483    Low Risk
# 37637    Low Risk
# 62729    Low Risk
# 99105    Low Risk
#
# [660 rows x 9 columns]

# %%
medium_risk_transactions.head(50)
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
#
# 118444                     NaN          Matalan  2023-07-01 13:15:00
# 164680                     NaN   Loosely Fitted  2023-09-09 12:19:00
# 46758                      NaN         Fat Face  2023-03-05 16:42:00
# 164639                     NaN          Revella  2023-09-09 11:34:00
# 19113                      NaN          Topshop  2023-01-28 14:28:00
# 167365                     NaN          Topshop  2023-09-14 16:51:00
# 130586                     NaN          Revella  2023-07-26 16:50:00
# 19498                      NaN          Topshop  2023-01-29 12:50:00
# 47674              518466565.0              NaN  2023-03-08 09:19:00
# 175817                     NaN             Wool  2023-09-30 09:53:00
# 91999              518746136.0              NaN  2023-05-29 08:40:00
# 151000                     NaN       Selfridges  2023-08-25 10:09:00
# 10764              307358402.0              NaN  2023-01-11 03:37:00
# 196538                     NaN          Matalan  2023-10-29 12:37:00
# 145871                     NaN   Loosely Fitted  2023-08-14 15:11:00
# 159912                     NaN          Topshop  2023-09-01 12:20:00
# 212884             280098744.0              NaN  2023-11-17 17:08:00
# 10340                      NaN    Sports Direct  2023-01-10 09:30:00
# 92238                      NaN    Fitted Stitch  2023-05-29 18:09:00
# 16397                      NaN          Topshop  2023-01-22 12:08:00
# 19054                      NaN         Fat Face  2023-01-28 13:21:00
# 9389                       NaN      Gamestation  2023-01-08 13:58:00
# 124377             654329190.0              NaN  2023-07-13 01:20:00
# 80860                      NaN          Revella  2023-05-02 13:38:00
# 10978                      NaN              CeX  2023-01-11 11:32:00
# 34955                      NaN          Matalan  2023-02-19 11:52:00
# 83912              335698481.0              NaN  2023-05-09 08:09:00
# 162532                     NaN          Topshop  2023-09-05 10:59:00
# 147171                     NaN          Revella  2023-08-17 09:45:00
#
#        risk_level
# 105470  High Risk
# 107134  High Risk
# 98684   High Risk
# 17541   High Risk
# 28469   High Risk
# 85382   High Risk
# 6859    High Risk
# 66473   High Risk
# 63178   High Risk
# 38042   High Risk
# 55791   High Risk
# 141565  High Risk
# 140327  High Risk
# 27181   High Risk
# 124559  High Risk
# 80223   High Risk
# 113074  High Risk
# 68422   High Risk
# 30403   High Risk
# 49892   High Risk
# 207559  High Risk
# 118444  High Risk
# 164680  High Risk
# 46758   High Risk
# 164639  High Risk
# 19113   High Risk
# 167365  High Risk
# 130586  High Risk
# 19498   High Risk
# 47674   High Risk
# 175817  High Risk
# 91999   High Risk
# 151000  High Risk
# 10764   High Risk
# 196538  High Risk
# 145871  High Risk
# 159912  High Risk
# 212884  High Risk
# 10340   High Risk
# 92238   High Risk
# 16397   High Risk
# 19054   High Risk
# 9389    High Risk
# 124377  High Risk
# 80860   High Risk
# 10978   High Risk
# 34955   High Risk
# 83912   High Risk
# 162532  High Risk
# 147171  High Risk

# %%
filtered = anomaly_detection_by_expenditures_df.loc[anomaly_detection_by_expenditures_df.index== 835736339.0]
filtered
# Out:
#               0.25    0.5    0.75     IQR  Overall_Threshold_1_IQR  \
# Account No
# 835736339.0  14.99  31.99  68.985  53.995                 149.9775
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 835736339.0                   230.97                   338.96
#
#                        Third_Party_Account_Threshold_1  \
# Account No
# 835736339.0  {175452235.0: 1310.0, 799306089.0: 130.0}
#
#                        Third_Party_Account_Threshold_2  \
# Account No
# 835736339.0  {175452235.0: 1310.0, 799306089.0: 130.0}
#
#                        Third_Party_Account_Threshold_3  \
# Account No
# 835736339.0  {175452235.0: 1310.0, 799306089.0: 130.0}
#
#                                           Business_Threshold_1  \
# Account No
# 835736339.0  {'AMAZON': 26.09, 'Amazon': 20.575000000000003...
#
#                                           Business_Threshold_2  \
# Account No
# 835736339.0  {'AMAZON': 26.09, 'Amazon': 30.715000000000003...
#
#                                           Business_Threshold_3  \
# Account No
# 835736339.0  {'AMAZON': 26.09, 'Amazon': 44.23500000000001,...
#
#                   user_user_interaction  \
# Account No
# 835736339.0  [175452235.0, 799306089.0]
#
#                                      user_business_interaction
# Account No
# 835736339.0  [AMAZON, Amazon, Blackwell's, Blizzard, Brilli...

# %%
copied_simulated_tx_df
# Out:
#               Date Timestamp   Account No       Balance   Amount  \
# 0       01/01/2023  00:00:00  678330503.0   2971.000000  1584.00
# 1       01/01/2023  00:00:00  472213568.0   3792.000000  1950.00
# 2       01/01/2023  00:00:00  472213568.0   3012.000000  -780.00
# 3       01/01/2023  00:00:00  283027736.0   1787.000000   780.00
# 4       01/01/2023  00:00:00  624500124.0   3226.000000  1825.00
# ...            ...       ...          ...           ...      ...
# 229189  06/12/2023  20:54:00  581655972.0  45935.206861   -41.06
# 229190  06/12/2023  20:55:00  786141370.0   -244.837500   -62.35
# 229191  06/12/2023  21:05:00  824916823.0   9709.172159   -32.94
# 229192  06/12/2023  21:13:00  366550080.0  26834.165794   -19.25
# 229193  06/12/2023  21:32:00  259015404.0   1145.349837   -37.64
#
#         Third Party Account No    Third Party Name             Datetime
# 0                          NaN  Westport Care Home  2023-01-01 00:00:00
# 1                          NaN    Barbiee Boutique  2023-01-01 00:00:00
# 2                  283027736.0                 NaN  2023-01-01 00:00:00
# 3                  472213568.0                 NaN  2023-01-01 00:00:00
# 4                          NaN            Fat Face  2023-01-01 00:00:00
# ...                        ...                 ...                  ...
# 229189                     NaN               Tesco  2023-12-06 20:54:00
# 229190                     NaN     Sainsbury Local  2023-12-06 20:55:00
# 229191                     NaN           Deliveroo  2023-12-06 21:05:00
# 229192                     NaN              Amazon  2023-12-06 21:13:00
# 229193                     NaN             JustEat  2023-12-06 21:32:00
#
# [229194 rows x 8 columns]

# %%
filtered_df = copied_simulated_tx_df[(copied_simulated_tx_df['Account No'] == 835736339.0) & (copied_simulated_tx_df['Third Party Account No'] == 175452235.0)]
filtered_df

# %% [markdown]
# ## Trialling it but with standard deviations instead of IQR

# %%
# Calculate the mean and std for each account
mean_std = expenditures_training_df.groupby('Account No')['Amount'].agg(['mean', 'std'])

# Establishing thresholds based on standard deviations from the mean
mean_std['Threshold_1_STD'] = mean_std['mean'] + mean_std['std'] * 1  # 1 std from the mean
mean_std['Threshold_2_STD'] = mean_std['mean'] + mean_std['std'] * 2  # 2 stds from the mean
mean_std['Threshold_3_STD'] = mean_std['mean'] + mean_std['std'] * 3  # 3 stds from the mean

# Your anomaly detection DataFrame now is mean_std with the standard deviation thresholds
anomaly_detection_by_expenditures_std_df = mean_std

# Renaming the index to 'Account No' if needed
anomaly_detection_by_expenditures_std_df.index.rename('Account No', inplace=True)

anomaly_detection_by_expenditures_std_df
# Out:
#                    mean         std  Threshold_1_STD  Threshold_2_STD  \
# Account No
# 101531259.0  144.838889  233.467999       378.306888       611.774887
# 104832000.0  163.088521  264.414059       427.502580       691.916638
# 105375973.0   65.442164   61.191660       126.633824       187.825485
# 106601471.0   42.777440   54.443285        97.220725       151.664010
# 108481285.0   45.203257  141.339078       186.542334       327.881412
# ...                 ...         ...              ...              ...
# 995615876.0  103.256101  154.510743       257.766843       412.277586
# 996042490.0  132.843302  307.622930       440.466232       748.089162
# 998390769.0  159.009848  278.233896       437.243744       715.477640
# 998405607.0   59.445659   54.433578       113.879237       168.312816
# 999752672.0   95.799121  175.361506       271.160627       446.522133
#
#              Threshold_3_STD
# Account No
# 101531259.0       845.242886
# 104832000.0       956.330697
# 105375973.0       249.017145
# 106601471.0       206.107295
# 108481285.0       469.220490
# ...                      ...
# 995615876.0       566.788328
# 996042490.0      1055.712092
# 998390769.0       993.711536
# 998405607.0       222.746394
# 999752672.0       621.883640
#
# [976 rows x 5 columns]

# %%
def calculate_thresholds_sd(group, multiplier):
    mean = group['Amount'].mean()
    std_dev = group['Amount'].std()
    threshold = mean + (multiplier * std_dev)
    return threshold

# %%
# For Threshold 1 (1 * Standard Deviation)
thresholds_1 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 1)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_1']))).to_dict()

# For Threshold 2 (2 * Standard Deviation)
thresholds_2 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 2)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_2']))).to_dict()

# For Threshold 3 (3 * Standard Deviation)
thresholds_3 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 3)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_3']))).to_dict()

# %%
anomaly_detection_by_expenditures_std_df['Business_Threshold_1'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Business_Threshold_2'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Business_Threshold_3'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# For Threshold 1 (1 * Standard Deviation)
thresholds_1 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 1)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_1']))).to_dict()

# For Threshold 2 (2 * Standard Deviation)
thresholds_2 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 2)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_2']))).to_dict()

# For Threshold 3 (3 * Standard Deviation)
thresholds_3 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_3']))).to_dict()

# %%
anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_1'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_2'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_3'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# Extracting keys from 'Business_Threshold_1' to create 'user_business_interaction'
anomaly_detection_by_expenditures_std_df['user_business_interaction'] = anomaly_detection_by_expenditures_std_df['Business_Threshold_1'].apply(
    lambda x: [key for key, value in x.items() if not np.isnan(value)] if isinstance(x, dict) else None
)


anomaly_detection_by_expenditures_std_df['user_user_interaction'] = anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# %%
def get_threshold_value(user_data, key, business=None):
    value = user_data.get(key, 0)
    if isinstance(value, dict):
        return value.get(business, float('inf'))

def assess_transaction_risk(account_no, amount, third_party_account_no, third_party_name, anomaly_detection_df):
    if amount >= 0:  # Skip payments
        return "Not Applicable"
    
    # Convert the amount to positive for comparison
    amount = abs(amount)
    risk_level = "No Risk"
    user_data = anomaly_detection_df.loc[account_no].to_dict()

    
    # Initialise interactions as empty lists to ensure they're iterable
    user_user_interaction = user_data.get('user_user_interaction', []) or []
    user_business_interaction = user_data.get('user_business_interaction', []) or []
    
    # Check if third_party_account_no is not None and is in user_user_interaction
    if third_party_account_no and third_party_account_no in user_user_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_1', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_2', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_3', third_party_account_no)
        ]
    # Check if industry_category is determined and in user_industry_interaction
    elif third_party_name and third_party_name in user_business_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Business_Threshold_1', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_2', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_3', third_party_name)
        ]
    else:
        # Use general thresholds if no specific interaction is found
        thresholds = [user_data['Threshold_1_STD'], user_data['Threshold_2_STD'], user_data['Threshold_3_STD']]
    
    if amount > thresholds[2]:
        risk_level = "High Risk"
    elif amount > thresholds[1]:
        risk_level = "Medium Risk"
    elif amount > thresholds[0]:
        risk_level = "Low Risk"
    
    return risk_level




risk_levels = [
    assess_transaction_risk(
        row['Account No'], row['Amount'], row.get('Third Party Account No'), row['Third Party Name'],
        anomaly_detection_by_expenditures_std_df
    ) for index, row in testing_transactions.iterrows()
]

testing_transactions['risk_level'] = risk_levels


testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 110276  26/06/2023  05:13:00  547010927.0  14786.249167   -7.74
# 113678  01/07/2023  00:00:00  986774156.0   1666.714362 -939.00
# 102644  09/06/2023  03:36:00  183888402.0  13918.517600  -36.25
# 98481   01/06/2023  08:12:00  822718326.0   6732.194082   -9.13
# 135544  31/07/2023  23:59:00  494156986.0   -312.797554   -7.99
# ...            ...       ...          ...           ...     ...
# 55831   30/03/2023  12:53:00  635679314.0   -976.793829  -96.68
# 188677  14/10/2023  10:39:00  421881811.0   3080.374643  -36.11
# 96461   31/05/2023  23:59:00  593191200.0   1764.992250  -18.99
# 182205  02/10/2023  12:43:00  165691047.0     98.783000 -148.00
# 196583  29/10/2023  13:32:00  297823329.0     86.226450  -15.98
#
#         Third Party Account No   Third Party Name             Datetime  \
# 110276                     NaN             Amazon  2023-06-26 05:13:00
# 113678                     NaN                LBG  2023-07-01 00:00:00
# 102644                     NaN            JustEat  2023-06-09 03:36:00
# 98481                      NaN              Tesco  2023-06-01 08:12:00
# 135544                     NaN             Disney  2023-07-31 23:59:00
# ...                        ...                ...                  ...
# 55831                      NaN              Tesco  2023-03-30 12:53:00
# 188677                     NaN  Brilliant Brushes  2023-10-14 10:39:00
# 96461                      NaN            PureGym  2023-05-31 23:59:00
# 182205                     NaN            Matalan  2023-10-02 12:43:00
# 196583                     NaN        Blackwell's  2023-10-29 13:32:00
#
#          risk_level
# 110276      No Risk
# 113678      No Risk
# 102644      No Risk
# 98481       No Risk
# 135544    High Risk
# ...             ...
# 55831      Low Risk
# 188677      No Risk
# 96461       No Risk
# 182205  Medium Risk
# 196583      No Risk
#
# [22920 rows x 9 columns]

# %%
risk_level_counts = testing_transactions['risk_level'].value_counts()
print(risk_level_counts)
# Out:
# No Risk           18348
# Low Risk           2165
# Not Applicable      974
# High Risk           799
# Medium Risk         634
# Name: risk_level, dtype: int64

# %%
# Filter for Low Risk transactions
low_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'Low Risk']

# Filter for Medium Risk transactions
medium_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'Medium Risk']

# Filter for High Risk transactions
high_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'High Risk']

# Filter for Not Applicable transactions
not_applicable_transactions = testing_transactions[testing_transactions['risk_level'] == 'Not Applicable']

# %%
high_risk_transactions.head(50)
# Out:
#               Date Timestamp   Account No      Balance   Amount  \
# 135544  31/07/2023  23:59:00  494156986.0  -312.797554    -7.99
# 151550  26/08/2023  12:15:00  679911053.0   945.240047  -184.98
# 137923  31/07/2023  23:59:00  727417797.0  4729.346500    -7.99
# 173444  26/09/2023  17:41:00  120634201.0  3221.403500   -40.00
# 102428  08/06/2023  11:37:00  604288474.0  3600.401233   -82.75
# 136816  31/07/2023  23:59:00  221356538.0   885.416100    -7.99
# 158335  31/08/2023  23:59:00  899692478.0 -1127.104444    -7.99
# 69143   17/04/2023  10:10:00  613729471.0  5848.725363  -167.30
# 127313  19/07/2023  13:06:00  767447966.0  3894.943815    -6.00
# 61559   31/03/2023  23:59:00  672994751.0   484.535350    -7.99
# 23588   31/01/2023  23:59:00  661295096.0  2027.051850    -7.99
# 2863    01/01/2023  00:00:00  796709231.0   687.020000    -7.99
# 8939    07/01/2023  16:28:00  254018059.0   185.526850  -170.00
# 135079  31/07/2023  23:59:00  421475159.0  -481.331737    -7.99
# 32950   14/02/2023  09:55:00  941285623.0   781.200857  -119.97
# 14607   18/01/2023  15:47:00  643610517.0   127.140309  -233.77
# 169307  18/09/2023  12:21:00  766941757.0  8161.975665  -147.00
# 41664   28/02/2023  23:59:00  581618317.0  -676.280302    -7.99
# 32950                      NaN       Gamestation  2023-02-14 09:55:00
# 14607                      NaN          Fat Face  2023-01-18 15:47:00
# 169307                     NaN           Matalan  2023-09-18 12:21:00
# 41664                      NaN            Amazon  2023-02-28 23:59:00
# 61089                      NaN            Disney  2023-03-31 23:59:00
# 54774                      NaN           Revella  2023-03-27 08:54:00
# 23351                      NaN            Disney  2023-01-31 23:59:00
# 78918                      NaN            Amazon  2023-04-30 23:59:00
# 116034                     NaN            Disney  2023-06-30 23:59:00
# 25480                      NaN            Amazon  2023-01-31 23:59:00
# 60873                      NaN            Amazon  2023-03-31 23:59:00
# 43502                      NaN            Amazon  2023-02-28 23:59:00
# 11545                      NaN              Wool  2023-01-12 13:16:00
# 28958                      NaN    Loosely Fitted  2023-02-05 15:56:00
# 60307                      NaN            Amazon  2023-03-31 23:59:00
# 178623                     NaN            Amazon  2023-09-30 23:59:00
# 193054                     NaN          Fat Face  2023-10-22 14:08:00
# 3711                       NaN            Disney  2023-01-01 00:00:00
# 17009                      NaN          Fat Face  2023-01-23 16:43:00
# 223542                     NaN            Disney  2023-11-30 23:59:00
# 139688                     NaN     Sports Direct  2023-08-02 17:50:00
# 113022                     NaN     Fitted Stitch  2023-06-30 17:31:00
# 179479                     NaN            Amazon  2023-09-30 23:59:00
# 99757                      NaN         The Works  2023-06-03 09:22:00
# 78897                      NaN            Disney  2023-04-30 23:59:00
# 142843                     NaN           Revella  2023-08-08 16:22:00
# 77640                      NaN            Disney  2023-04-30 23:59:00
# 24679                      NaN            Disney  2023-01-31 23:59:00
# 194759                     NaN   Lloyds Pharmacy  2023-10-26 06:52:00
# 47603              460463595.0               NaN  2023-03-08 07:21:00
# 155979                     NaN            Amazon  2023-08-31 23:59:00
# 61903                      NaN            Amazon  2023-03-31 23:59:00
# 180335                     NaN            Amazon  2023-09-30 23:59:00
# 77793                      NaN            Amazon  2023-04-30 23:59:00
# 200213                     NaN            Disney  2023-10-31 23:59:00
# 23464                      NaN            Disney  2023-01-31 23:59:00
#
#        risk_level
# 135544  High Risk
# 151550  High Risk
# 137923  High Risk
# 173444  High Risk
# 102428  High Risk
# 136816  High Risk
# 158335  High Risk
# 69143   High Risk
# 127313  High Risk
# 61559   High Risk
# 23588   High Risk
# 2863    High Risk
# 8939    High Risk
# 135079  High Risk
# 32950   High Risk
# 14607   High Risk
# 169307  High Risk
# 41664   High Risk
# 61089   High Risk
# 54774   High Risk
# 23351   High Risk
# 78918   High Risk
# 116034  High Risk
# 25480   High Risk
# 60873   High Risk
# 43502   High Risk
# 11545   High Risk
# 28958   High Risk
# 60307   High Risk
# 178623  High Risk
# 193054  High Risk
# 3711    High Risk
# 17009   High Risk
# 223542  High Risk
# 139688  High Risk
# 113022  High Risk
# 179479  High Risk
# 99757   High Risk
# 78897   High Risk
# 142843  High Risk
# 77640   High Risk
# 24679   High Risk
# 194759  High Risk
# 47603   High Risk
# 155979  High Risk
# 61903   High Risk
# 180335  High Risk
# 77793   High Risk
# 200213  High Risk
# 23464   High Risk

# %%
filtered = anomaly_detection_by_expenditures_df.loc[anomaly_detection_by_expenditures_df.index== 585625048.0]
filtered
# Out:
#              0.25  0.5    0.75     IQR  Overall_Threshold_1_IQR  \
# Account No
# 585625048.0  5.99  7.8  51.985  45.995                 120.9775
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 585625048.0                   189.97                   281.96
#
#                       Third_Party_Account_Threshold_1  \
# Account No
# 585625048.0  {280990953.0: 3.03, 576188756.0: 4855.0}
#
#                       Third_Party_Account_Threshold_2  \
# Account No
# 585625048.0  {280990953.0: 3.03, 576188756.0: 6765.0}
#
#                       Third_Party_Account_Threshold_3  \
# Account No
# 585625048.0  {280990953.0: 3.03, 576188756.0: 8675.0}
#
#                                           Business_Threshold_1  \
# Account No
# 585625048.0  {'AMAZON': 78.9525, 'Amazon': 7.99, 'Blizzard'...
#
#                                           Business_Threshold_2  \
# Account No
# 585625048.0  {'AMAZON': 180.12, 'Amazon': 7.99, 'Blizzard':...
#
#                                           Business_Threshold_3  \
# Account No
# 585625048.0  {'AMAZON': 324.645, 'Amazon': 7.99, 'Blizzard'...
#
#                   user_user_interaction  \
# Account No
# 585625048.0  [280990953.0, 576188756.0]
#
#                                      user_industry_interaction  \
# Account No
# 585625048.0  [AMAZON, Amazon, Blizzard, CeX, Coffee #1, Coo...
#
#                                      user_business_interaction
# Account No
# 585625048.0  [AMAZON, Amazon, Blizzard, CeX, Coffee #1, Coo...

# %%
# Accessing 'user_industry_interaction' for a specific account
user_industry_interaction = filtered.loc[585625048.0, 'Business_Threshold_1']
print(user_industry_interaction)
# Out:
# {'AMAZON': 78.9525, 'Amazon': 7.99, 'Blizzard': 14.99, 'CeX': 29.99, 'Coffee #1': 7.831250000000001, 'Coop Local': 24.97, 'Deliveroo': 21.9, 'Etsy': 11.95, 'Fat Face': 291.53000000000003, 'Gamestation': 164.97, 'JustEat': 14.49, 'Lloyds Pharmacy': 71.63999999999999, 'Loosely Fitted': 46.58, 'Matalan': 395.67499999999995, 'Mojang Studios': 5.99, 'Netflix': 15.99, 'PureGym': 18.99, 'Reebok': 22.0, 'Revella': 498.75, 'Sports Direct': 267.72749999999996, 'SquareOnix': 12.99, 'Starbucks': 8.075, 'Tesco': 238.5125, 'Topshop': 367.67499999999995, 'Xbox': 7.0}

# %% [markdown]
# ### Feature engineering for anomaly detection: payments

# %%
# Calculating Q1, Q3, and IQR for each account in 'from_totally_fake_account'
quartiles = payments_training_df.groupby('Account No')['Amount'].quantile([0.25, 0.5, 0.75]).unstack()
quartiles['IQR'] = quartiles[0.75] - quartiles[0.25]

thresholds = quartiles.copy()
thresholds['Overall_Threshold_1_IQR'] = quartiles[0.75] + 1.5 * quartiles['IQR']
thresholds['Overall_Threshold_2_IQR'] = quartiles[0.75] + 3 * quartiles['IQR']
thresholds['Overall_Threshold_3_IQR'] = quartiles[0.75] + 5 * quartiles['IQR']

anomaly_detection_by_payments_df = thresholds

anomaly_detection_by_payments_df.index.rename('Account No', inplace=True)

anomaly_detection_by_payments_df
