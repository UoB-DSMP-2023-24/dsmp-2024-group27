# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
import ast
from matplotlib_venn import venn2

# %% [markdown]
# ### Loading the dataset

# %%
simulated_cleaned_tx_df = pd.read_csv('../SavedData/dataset2_cleaned.csv')

# %%
simulated_cleaned_tx_df
# Out:
#               Date Timestamp   Account No       Balance   Amount  \
# 0       01/01/2023  00:00:00  678330503.0   2971.000000  1584.00
# 1       01/01/2023  00:00:00  472213568.0   3792.000000  1950.00
# 2       01/01/2023  00:00:00  472213568.0   3012.000000  -780.00
# 3       01/01/2023  00:00:00  283027736.0   1787.000000   780.00
# 4       01/01/2023  00:00:00  624500124.0   3226.000000  1825.00
# ...            ...       ...          ...           ...      ...
# 229189  06/12/2023  20:54:00  581655972.0  45935.206861   -41.06
# 229190  06/12/2023  20:55:00  786141370.0   -244.837500   -62.35
# 229191  06/12/2023  21:05:00  824916823.0   9709.172159   -32.94
# 229192  06/12/2023  21:13:00  366550080.0  26834.165794   -19.25
# 229193  06/12/2023  21:32:00  259015404.0   1145.349837   -37.64
#
#         Third Party Account No    Third Party Name             Datetime
# 0                          NaN  Westport Care Home  2023-01-01 00:00:00
# 1                          NaN    Barbiee Boutique  2023-01-01 00:00:00
# 2                  283027736.0                 NaN  2023-01-01 00:00:00
# 3                  472213568.0                 NaN  2023-01-01 00:00:00
# 4                          NaN            Fat Face  2023-01-01 00:00:00
# ...                        ...                 ...                  ...
# 229189                     NaN               Tesco  2023-12-06 20:54:00
# 229190                     NaN     Sainsbury Local  2023-12-06 20:55:00
# 229191                     NaN           Deliveroo  2023-12-06 21:05:00
# 229192                     NaN              Amazon  2023-12-06 21:13:00
# 229193                     NaN             JustEat  2023-12-06 21:32:00
#
# [229194 rows x 8 columns]

# %% [markdown]
# ### Splitting the data into training and testing

# %%
copied_simulated_tx_df = simulated_cleaned_tx_df.copy()

# Splitting the copied dataset into historical_transactions (95%) and testing_transactions (5%)
training_transactions, testing_transactions = train_test_split(copied_simulated_tx_df, test_size=0.1, random_state=12)

# Displaying the shapes to verify the split
training_transactions.shape, testing_transactions.shape
# Out:
# ((206274, 8), (22920, 8))

# %%
testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
# [22920 rows x 8 columns]

# %%
# Creating copies of training and testing df for the std versions
training_transactions_copy= training_transactions.copy()
testing_transactions_copy= testing_transactions.copy()

# %% [markdown]
# ### Splitting the training transactions into payments and expenditures

# %%
payments_training_df = training_transactions[training_transactions['Amount'] > 0]
expenditures_training_df = training_transactions[training_transactions['Amount'] < 0]

# %%
# Taking the absolute values of the amount column
expenditures_training_df["Amount"] = expenditures_training_df["Amount"].abs()

expenditures_training_df
# Out:
# /var/folders/rw/215myrns4md_n1k8nkyww6mw0000gn/T/ipykernel_70074/721076894.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expenditures_training_df["Amount"] = expenditures_training_df["Amount"].abs()
#               Date Timestamp   Account No       Balance  Amount  \
# 215690  22/11/2023  18:12:00  496674181.0  -2187.525472  111.38
# 20958   31/01/2023  10:05:00  421881811.0   2363.284100   22.00
# 197261  30/10/2023  20:06:00  387957305.0  -2677.341106   37.99
# 63359   03/04/2023  08:51:00  120634201.0   1441.908700   41.04
# 6331    02/01/2023  18:47:00  713910252.0   2116.752100  140.49
# ...            ...       ...          ...           ...     ...
# 206083  05/11/2023  07:55:00  550169791.0  22875.430900   45.04
# 36482   23/02/2023  12:38:00  554792076.0   2248.810443   75.74
# 40177   01/03/2023  00:00:00  624563756.0    -14.727071  822.00
# 150781  24/08/2023  20:15:00  176922958.0   1440.312330   37.43
# 210763  13/11/2023  10:23:00  749378808.0   4130.408178  138.56
#
#         Third Party Account No Third Party Name             Datetime
# 215690                     NaN       Coop Local  2023-11-22 18:12:00
# 20958                      NaN    Sports Direct  2023-01-31 10:05:00
# 197261                     NaN            Tesco  2023-10-30 20:06:00
# 63359                      NaN            Tesco  2023-04-03 08:51:00
# 6331                       NaN            Tesco  2023-01-02 18:47:00
# ...                        ...              ...                  ...
# 206083                     NaN             Etsy  2023-11-05 07:55:00
# 36482                      NaN          Topshop  2023-02-23 12:38:00
# 40177                      NaN              LBG  2023-03-01 00:00:00
# 150781                     NaN        Deliveroo  2023-08-24 20:15:00
# 210763                     NaN         Fat Face  2023-11-13 10:23:00
#
# [196934 rows x 8 columns]

# %% [markdown]
# ## Creating an anomaly detection model using IQR for thresholds

# %%
# Step 1: Calculate Q1, Q3, and IQR
quartiles = expenditures_training_df.groupby('Account No')['Amount'].quantile([0.25, 0.5, 0.75]).unstack()
quartiles['IQR'] = quartiles[0.75] - quartiles[0.25]

# Initial thresholds based on IQR
quartiles['Overall_Threshold_1_IQR'] = quartiles[0.75] + 1.5 * quartiles['IQR']
quartiles['Overall_Threshold_2_IQR'] = quartiles[0.75] + 3 * quartiles['IQR']
quartiles['Overall_Threshold_3_IQR'] = quartiles[0.75] + 5 * quartiles['IQR']

# Step 2 & 3: Adjust thresholds if they are the same
# Define percentage increments for fallback
percent_increment_1 = 0.333  # Example: 10%
percent_increment_2 = 0.666 # Example: 20%
percent_increment_3 = 1  # Example: 30%

# Function to check and adjust thresholds
def adjust_thresholds(row):
    if row['Overall_Threshold_1_IQR'] == row['Overall_Threshold_2_IQR'] == row['Overall_Threshold_3_IQR']:
        median = row[0.5]
        row['Overall_Threshold_1_IQR'] = median * (1 + percent_increment_1)
        row['Overall_Threshold_2_IQR'] = median * (1 + percent_increment_2)
        row['Overall_Threshold_3_IQR'] = median * (1 + percent_increment_3)
    return row

# Apply adjustments
thresholds_adjusted = quartiles.apply(adjust_thresholds, axis=1)

# Step 4: Finalise the DataFrame
anomaly_detection_by_expenditures_df = thresholds_adjusted.copy()
anomaly_detection_by_expenditures_df.index.rename('Account No', inplace=True)

anomaly_detection_by_expenditures_df.head(30)
# Out:
#                 0.25      0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675   88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775   50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900   46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200   21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400   20.970   44.9200   35.4800                 98.14000
# 108563213.0  10.1100   23.390   58.9650   48.8550                132.24750
# 108812033.0  15.9900   37.945   99.9975   84.0075                226.00875
# 108931112.0  15.9900   35.225   75.1525   59.1625                163.89625
# 111137699.0  21.9600   67.170  182.0000  160.0400                422.06000
# 113747882.0  10.4000   22.370   37.5800   27.1800                 78.35000
# 116169597.0  36.2300   72.070  163.9100  127.6800                355.43000
# 116598243.0  11.4000   34.350   92.5300   81.1300                214.22500
# 117273481.0   5.8000    8.165   36.9725   31.1725                 83.73125
# 117308635.0  13.0200   30.530   81.3775   68.3575                183.91375
# 119943495.0   7.9900   35.560   92.4275   84.4375                219.08375
# 119993184.0  12.9900   26.595   69.4500   56.4600                154.14000
# 120634201.0  15.9725   22.300   72.4600   56.4875                157.19125
# 121113546.0  12.9900   30.960   98.7900   85.8000                227.49000
# 121858569.0  41.7700  100.000  169.7500  127.9800                361.72000
# 122884111.0  15.9900   34.190   99.9975   84.0075                226.00875
# 124102251.0  12.6350   25.460   63.2150   50.5800                139.08500
# 124125096.0  14.9900   38.930   94.4400   79.4500                213.61500
# 124377686.0  15.9900   31.005   81.6450   65.6550                180.12750
# 126929801.0  15.9900   47.590  100.0000   84.0100                226.01500
# 127809299.0  16.5500   40.645   77.4925   60.9425                168.90625
# 128030172.0  15.9900   40.880   80.3000   64.3100                176.76500
# 128033695.0  11.1075   18.990   36.9325   25.8250                 75.67000
# 129018172.0  14.9900   30.660  149.3175  134.3275                350.80875
# 130154096.0  15.9900   35.950  111.7400   95.7500                255.36500
# 130522384.0  15.9900   49.990  121.5000  105.5100                279.76500
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# 108563213.0                 205.5300                 303.2400
# 108812033.0                 352.0200                 520.0350
# 108931112.0                 252.6400                 370.9650
# 111137699.0                 662.1200                 982.2000
# 113747882.0                 119.1200                 173.4800
# 116169597.0                 546.9500                 802.3100
# 116598243.0                 335.9200                 498.1800
# 117273481.0                 130.4900                 192.8350
# 117308635.0                 286.4500                 423.1650
# 119943495.0                 345.7400                 514.6150
# 119993184.0                 238.8300                 351.7500
# 120634201.0                 241.9225                 354.8975
# 121113546.0                 356.1900                 527.7900
# 121858569.0                 553.6900                 809.6500
# 122884111.0                 352.0200                 520.0350
# 124102251.0                 214.9550                 316.1150
# 124125096.0                 332.7900                 491.6900
# 124377686.0                 278.6100                 409.9200
# 126929801.0                 352.0300                 520.0500
# 127809299.0                 260.3200                 382.2050
# 128030172.0                 273.2300                 401.8500
# 128033695.0                 114.4075                 166.0575
# 129018172.0                 552.3000                 820.9550
# 130154096.0                 398.9900                 590.4900
# 130522384.0                 438.0300                 649.0500

# %% [markdown]
# ### Creating thresholds for each user to user transfers

# %%
# Threshold function
def calculate_thresholds(group, multiplier):
#     if len(group) <= 1:  # Check if there's only one expenditure
#         return np.nan  # Indicative value for groups with only one transaction
    quantiles = group['Amount'].quantile([0.25, 0.75])
    IQR = quantiles[0.75] - quantiles[0.25]
    threshold = quantiles[0.75] + multiplier * IQR
    return threshold

# %%
# Applying the adjusted function for each threshold calculation with different multipliers

# For Threshold 1 (1.5 * IQR)
thresholds_1 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 1.5)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_1']))).to_dict()

# For Threshold 2 (3 * IQR)
thresholds_2 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_2']))).to_dict()

# For Threshold 3 (5 * IQR)
thresholds_3 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 5)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_3']))).to_dict()

anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_1'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_2'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_3'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 670.0}            {587923845.0: 670.0}
# 105375973.0                             NaN                             NaN
# 106601471.0                             NaN                             NaN
# 108481285.0           {913801979.0: 2185.0}           {913801979.0: 2552.5}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0           {792845450.0: 1500.0}           {792845450.0: 1500.0}
# 998390769.0                             NaN                             NaN
# 998405607.0                             NaN                             NaN
# 999752672.0            {211493028.0: 680.0}            {211493028.0: 680.0}
#
#             Third_Party_Account_Threshold_3
# Account No
# 101531259.0                             NaN
# 104832000.0            {587923845.0: 670.0}
# 105375973.0                             NaN
# 106601471.0                             NaN
# 108481285.0           {913801979.0: 3042.5}
# ...                                     ...
# 995615876.0                             NaN
# 996042490.0           {792845450.0: 1500.0}
# 998390769.0                             NaN
# 998405607.0                             NaN
# 999752672.0            {211493028.0: 680.0}
#
# [976 rows x 10 columns]

# %% [markdown]
# ### Creating thresholds for each user to business transactions

# %%
# For Threshold 1 (1.5 * IQR)
thresholds_1 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 1.5)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_1']))).to_dict()

# For Threshold 2 (3 * IQR)
thresholds_2 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_2']))).to_dict()

# For Threshold 3 (5 * IQR)
thresholds_3 = expenditures_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 5)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_3']))).to_dict()

anomaly_detection_by_expenditures_df['Business_Threshold_1'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_df['Business_Threshold_2'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_df['Business_Threshold_3'] = anomaly_detection_by_expenditures_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 670.0}            {587923845.0: 670.0}
# 105375973.0                             NaN                             NaN
# 106601471.0                             NaN                             NaN
# 108481285.0           {913801979.0: 2185.0}           {913801979.0: 2552.5}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0           {792845450.0: 1500.0}           {792845450.0: 1500.0}
# 998390769.0                             NaN                             NaN
# 998405607.0                             NaN                             NaN
# 999752672.0            {211493028.0: 680.0}            {211493028.0: 680.0}
#
#             Third_Party_Account_Threshold_3  \
# Account No
# 101531259.0                             NaN
# 104832000.0            {587923845.0: 670.0}
# 105375973.0                             NaN
# 106601471.0                             NaN
# 108481285.0           {913801979.0: 3042.5}
# ...                                     ...
# 995615876.0                             NaN
# 996042490.0           {792845450.0: 1500.0}
# 998390769.0                             NaN
# 998405607.0                             NaN
# 999752672.0            {211493028.0: 680.0}
#
#                                           Business_Threshold_1  \
# Account No
# 101531259.0  {'Brilliant Brushes': 85.97999999999999, 'Deli...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.1950000000000003, 'Amazon': 102.7...
# 108481285.0  {'AMAZON': 38.41, 'Amazon': 35.025000000000006...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 33.9574999999...
# 996042490.0  {'Blackwell's': 41.94, 'Blizzard': 14.99, 'Boo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 8.14999999999999...
#
#                                           Business_Threshold_2  \
# Account No
# 101531259.0  {'Brilliant Brushes': 124.97999999999999, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.2475000000000005, 'Amazon': 145.3...
# 108481285.0  {'AMAZON': 53.8, 'Amazon': 51.27000000000001, ...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.37, 'Fat F...
# 996042490.0  {'Blackwell's': 50.925, 'Blizzard': 14.99, 'Bo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 9.79999999999999...
#
#                                           Business_Threshold_3
# Account No
# 101531259.0  {'Brilliant Brushes': 176.97999999999996, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.317500000000001, 'Amazon': 202.13...
# 108481285.0  {'AMAZON': 74.32, 'Amazon': 72.93, 'Blackwell'...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.9199999999...
# 996042490.0  {'Blackwell's': 62.90499999999999, 'Blizzard':...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 11.9999999999999...
#
# [976 rows x 13 columns]

# %%
# Extracting keys from 'transfer_to_accounts_threshold_1_IQR' to create 'user_user_interaction'
anomaly_detection_by_expenditures_df['user_user_interaction'] = anomaly_detection_by_expenditures_df['Third_Party_Account_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# Extracting keys from 'industry_threshold_1_IQR' to create 'user_industry_interaction'
anomaly_detection_by_expenditures_df['user_business_interaction'] = anomaly_detection_by_expenditures_df['Business_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

anomaly_detection_by_expenditures_df
# Out:
#                 0.25     0.5      0.75       IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  27.9675  88.580  117.7825   89.8150                252.50500
# 104832000.0  24.2775  50.950  117.4050   93.1275                257.09625
# 105375973.0  18.9900  46.030  114.0850   95.0950                256.72750
# 106601471.0  10.9200  21.970   44.5000   33.5800                 94.87000
# 108481285.0   9.4400  20.970   44.9200   35.4800                 98.14000
# ...              ...     ...       ...       ...                      ...
# 995615876.0  25.3925  54.735  109.2325   83.8400                234.99250
# 996042490.0  15.9900  34.490   93.4900   77.5000                209.74000
# 998390769.0  14.9900  69.980  131.7750  116.7850                306.95250
# 998405607.0  15.9900  41.305  100.0000   84.0100                226.01500
# 999752672.0   6.0500  18.445  108.9025  102.8525                263.18125
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                 387.2275                 566.8575
# 104832000.0                 396.7875                 583.0425
# 105375973.0                 399.3700                 589.5600
# 106601471.0                 145.2400                 212.4000
# 108481285.0                 151.3600                 222.3200
# ...                              ...                      ...
# 995615876.0                 360.7525                 528.4325
# 996042490.0                 325.9900                 480.9900
# 998390769.0                 482.1300                 715.7000
# 998405607.0                 352.0300                 520.0500
# 999752672.0                 417.4600                 623.1650
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 670.0}            {587923845.0: 670.0}
# 105375973.0                             NaN                             NaN
# 106601471.0                             NaN                             NaN
# 108481285.0           {913801979.0: 2185.0}           {913801979.0: 2552.5}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0           {792845450.0: 1500.0}           {792845450.0: 1500.0}
# 998390769.0                             NaN                             NaN
# 998405607.0                             NaN                             NaN
# 999752672.0            {211493028.0: 680.0}            {211493028.0: 680.0}
#
#             Third_Party_Account_Threshold_3  \
# Account No
# 101531259.0                             NaN
# 104832000.0            {587923845.0: 670.0}
# 105375973.0                             NaN
# 106601471.0                             NaN
# 108481285.0           {913801979.0: 3042.5}
# ...                                     ...
# 995615876.0                             NaN
# 996042490.0           {792845450.0: 1500.0}
# 998390769.0                             NaN
# 998405607.0                             NaN
# 999752672.0            {211493028.0: 680.0}
#
#                                           Business_Threshold_1  \
# Account No
# 101531259.0  {'Brilliant Brushes': 85.97999999999999, 'Deli...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.1950000000000003, 'Amazon': 102.7...
# 108481285.0  {'AMAZON': 38.41, 'Amazon': 35.025000000000006...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 33.9574999999...
# 996042490.0  {'Blackwell's': 41.94, 'Blizzard': 14.99, 'Boo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 8.14999999999999...
#
#                                           Business_Threshold_2  \
# Account No
# 101531259.0  {'Brilliant Brushes': 124.97999999999999, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.2475000000000005, 'Amazon': 145.3...
# 108481285.0  {'AMAZON': 53.8, 'Amazon': 51.27000000000001, ...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.37, 'Fat F...
# 996042490.0  {'Blackwell's': 50.925, 'Blizzard': 14.99, 'Bo...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 9.79999999999999...
#
#                                           Business_Threshold_3  \
# Account No
# 101531259.0  {'Brilliant Brushes': 176.97999999999996, 'Del...
# 104832000.0  {'A Cut Above': 200.0, 'Blizzard': 14.99, 'Boo...
# 105375973.0  {'AMAZON': 36.06, 'Amazon': 7.99, 'Blackwell's...
# 106601471.0  {'AMAZON': 3.317500000000001, 'Amazon': 202.13...
# 108481285.0  {'AMAZON': 74.32, 'Amazon': 72.93, 'Blackwell'...
# ...                                                        ...
# 995615876.0  {'Blizzard': 14.99, 'Deliveroo': 34.9199999999...
# 996042490.0  {'Blackwell's': 62.90499999999999, 'Blizzard':...
# 998390769.0  {'Amazon': 5.99, 'Blizzard': 14.99, 'Deliveroo...
# 998405607.0  {'Blackwell's': 32.96, 'Blizzard': 14.99, 'Del...
# 999752672.0  {'AMAZON': 11.6, 'Coffee #1': 11.9999999999999...
#
#             user_user_interaction  \
# Account No
# 101531259.0                  None
# 104832000.0         [587923845.0]
# 105375973.0                  None
# 106601471.0                  None
# 108481285.0         [913801979.0]
# ...                           ...
# 995615876.0                  None
# 996042490.0         [792845450.0]
# 998390769.0                  None
# 998405607.0                  None
# 999752672.0         [211493028.0]
#
#                                      user_business_interaction
# Account No
# 101531259.0  [Brilliant Brushes, Deliveroo, Disney, Fat Fac...
# 104832000.0  [A Cut Above, Blizzard, Boots, Deliveroo, Etsy...
# 105375973.0  [AMAZON, Amazon, Blackwell's, Coop Local, Deli...
# 106601471.0  [AMAZON, Amazon, Blackwell's, Blizzard, Boots,...
# 108481285.0  [AMAZON, Amazon, Blackwell's, Boots, Brilliant...
# ...                                                        ...
# 995615876.0  [Blizzard, Deliveroo, Fat Face, Gamestation, J...
# 996042490.0  [Blackwell's, Blizzard, Boots, Brilliant Brush...
# 998390769.0  [Amazon, Blizzard, Deliveroo, Disney, Fat Face...
# 998405607.0  [Blackwell's, Blizzard, Deliveroo, Fat Face, F...
# 999752672.0  [AMAZON, Coffee #1, Coop Local, Deliveroo, Ets...
#
# [976 rows x 15 columns]

# %% [markdown]
# ### Feature engineering for anomaly detection: payments

# %%
payments_training_df
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 38370   28/02/2023  00:00:00  449871732.0   3032.563257  2870.0
# 134053  31/07/2023  23:59:00  548907062.0    -28.522061   690.0
# 219453  30/11/2023  00:00:00  179173981.0   5187.405221  1825.0
# 154062  31/08/2023  00:00:00  948069469.0    780.222400  1706.0
# 75623   01/05/2023  00:00:00  147474476.0   5397.416725  3125.0
# ...            ...       ...          ...           ...     ...
# 197631  31/10/2023  00:00:00  730002588.0  15670.657676  3957.0
# 153856  31/08/2023  00:00:00  679943657.0   4151.488450  2918.0
# 74313   30/04/2023  00:00:00  987163717.0   5244.930000  2292.0
# 112086  30/06/2023  00:00:00  651756497.0  11431.655433  4375.0
# 57433   01/04/2023  00:00:00  119993184.0   1305.598347  1712.0
#
#         Third Party Account No             Third Party Name  \
# 38370                      NaN                      Jollyes
# 134053             865748375.0                          NaN
# 219453                     NaN                      Matalan
# 154062                     NaN              Happy Days Home
# 75623                      NaN              Premier Finance
# ...                        ...                          ...
# 197631                     NaN                      Halifax
# 153856                     NaN  University College Hospital
# 74313                      NaN                          CPA
# 112086                     NaN                          CPA
# 57433                      NaN           Westport Care Home
#
#                    Datetime
# 38370   2023-02-28 00:00:00
# 134053  2023-07-31 23:59:00
# 219453  2023-11-30 00:00:00
# 154062  2023-08-31 00:00:00
# 75623   2023-05-01 00:00:00
# ...                     ...
# 197631  2023-10-31 00:00:00
# 153856  2023-08-31 00:00:00
# 74313   2023-04-30 00:00:00
# 112086  2023-06-30 00:00:00
# 57433   2023-04-01 00:00:00
#
# [9331 rows x 8 columns]

# %%
# Step 1: Calculate Q1, Q3, and IQR
quartiles = payments_training_df.groupby('Account No')['Amount'].quantile([0.25, 0.5, 0.75]).unstack()
quartiles['IQR'] = quartiles[0.75] - quartiles[0.25]

# Initial thresholds based on IQR
quartiles['Overall_Threshold_1_IQR'] = quartiles[0.75] + 1.5 * quartiles['IQR']
quartiles['Overall_Threshold_2_IQR'] = quartiles[0.75] + 3 * quartiles['IQR']
quartiles['Overall_Threshold_3_IQR'] = quartiles[0.75] + 5 * quartiles['IQR']

# Step 2 & 3: Adjust thresholds if they are the same
# Define percentage increments for fallback
percent_increment_1 = 0.333  # Example: 33.3%
percent_increment_2 = 0.667 # Example: 66.7%
percent_increment_3 = 1   # Example: 90%

# Function to check and adjust thresholds
def adjust_thresholds(row):
    if row['Overall_Threshold_1_IQR'] == row['Overall_Threshold_2_IQR'] == row['Overall_Threshold_3_IQR']:
        median = row[0.5]
        row['Overall_Threshold_1_IQR'] = median * (1 + percent_increment_1)
        row['Overall_Threshold_2_IQR'] = median * (1 + percent_increment_2)
        row['Overall_Threshold_3_IQR'] = median * (1 + percent_increment_3)
    return row

# Apply adjustments
thresholds_adjusted = quartiles.apply(adjust_thresholds, axis=1)

# Step 4: Finalise the DataFrame
anomaly_detection_by_payments_df = thresholds_adjusted.copy()
anomaly_detection_by_payments_df.index.rename('Account No', inplace=True)

anomaly_detection_by_payments_df.head(30)
# Out:
#                 0.25      0.5     0.75    IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  1542.50  1542.50  1542.50    0.0               2056.15250
# 104832000.0  1675.00  1675.00  1675.00    0.0               2232.77500
# 105375973.0   900.00   900.00   900.00    0.0               1199.70000
# 106601471.0  1675.00  1675.00  1675.00    0.0               2232.77500
# 108481285.0   640.00   640.00  1584.00  944.0               3000.00000
# 108563213.0  3749.00  3749.00  3749.00    0.0               4997.41700
# 108812033.0   830.00   830.00   830.00    0.0               1106.39000
# 108931112.0  4779.00  4779.00  4779.00    0.0               6370.40700
# 111137699.0  1675.00  1675.00  1675.00    0.0               2232.77500
# 113747882.0  2475.00  2475.00  2475.00    0.0               3299.17500
# 116169597.0  1542.50  1542.50  1542.50    0.0               2056.15250
# 116598243.0  1706.00  1706.00  1706.00    0.0               2274.09800
# 117273481.0  3376.00  3376.00  3376.00    0.0               4500.20800
# 117308635.0  1200.00  1200.00  1200.00    0.0               1599.60000
# 119943495.0   400.00   400.00   400.00    0.0                533.20000
# 119993184.0  1712.00  1712.00  1712.00    0.0               2282.09600
# 120634201.0  2601.00  2601.00  2601.00    0.0               3467.13300
# 121113546.0   410.00   410.00   410.00    0.0                546.53000
# 121858569.0  3750.00  3750.00  3750.00    0.0               4998.75000
# 122884111.0  1580.00  1820.00  1920.00  340.0               2430.00000
# 124102251.0  1916.60  1916.60  1916.60    0.0               2554.82780
# 124125096.0  2641.66  2641.66  2641.66    0.0               3521.33278
# 126929801.0  1842.50  1842.50  1842.50    0.0               2456.05250
# 127809299.0   405.00   580.00   580.00  175.0                842.50000
# 128030172.0   280.00   280.00   280.00    0.0                373.24000
# 128033695.0  1620.10  1620.10  1620.10    0.0               2159.59330
# 129018172.0  2916.60  2916.60  2916.60    0.0               3887.82780
# 130154096.0  2708.00  2708.00  2708.00    0.0               3609.76400
# 130522384.0  1736.92  1736.92  1736.92    0.0               2315.31436
# 131388684.0  4375.00  4375.00  4375.00    0.0               5831.87500
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR
# Account No
# 101531259.0               2571.34750                  3085.00
# 104832000.0               2792.22500                  3350.00
# 105375973.0               1500.30000                  1800.00
# 106601471.0               2792.22500                  3350.00
# 108481285.0               4416.00000                  6304.00
# 108563213.0               6249.58300                  7498.00
# 108812033.0               1383.61000                  1660.00
# 108931112.0               7966.59300                  9558.00
# 111137699.0               2792.22500                  3350.00
# 113747882.0               4125.82500                  4950.00
# 116169597.0               2571.34750                  3085.00
# 116598243.0               2843.90200                  3412.00
# 117273481.0               5627.79200                  6752.00
# 117308635.0               2000.40000                  2400.00
# 119943495.0                666.80000                   800.00
# 119993184.0               2853.90400                  3424.00
# 120634201.0               4335.86700                  5202.00
# 121113546.0                683.47000                   820.00
# 121858569.0               6251.25000                  7500.00
# 122884111.0               2940.00000                  3620.00
# 124102251.0               3194.97220                  3833.20
# 124125096.0               4403.64722                  5283.32
# 126929801.0               3071.44750                  3685.00
# 127809299.0               1105.00000                  1455.00
# 128030172.0                466.76000                   560.00
# 128033695.0               2700.70670                  3240.20
# 129018172.0               4861.97220                  5833.20
# 130154096.0               4514.23600                  5416.00
# 130522384.0               2895.44564                  3473.84
# 131388684.0               7293.12500                  8750.00

# %%
thresholds_1 = payments_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 1.5)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_1']))).to_dict()

# For Threshold 2 (3 * IQR)
thresholds_2 = payments_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_2']))).to_dict()

# For Threshold 3 (5 * IQR)
thresholds_3 = payments_training_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 5)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_3']))).to_dict()

anomaly_detection_by_payments_df['Third_Party_Account_Threshold_1'] = anomaly_detection_by_payments_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_payments_df['Third_Party_Account_Threshold_2'] = anomaly_detection_by_payments_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_payments_df['Third_Party_Account_Threshold_3'] = anomaly_detection_by_payments_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# For Threshold 1 (1.5 * IQR)
thresholds_1 = payments_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 1.5)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_1']))).to_dict()

# For Threshold 2 (3 * IQR)
thresholds_2 = payments_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_2']))).to_dict()

# For Threshold 3 (5 * IQR)
thresholds_3 = payments_training_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds(group, 5)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_3']))).to_dict()

anomaly_detection_by_payments_df['Business_Threshold_1'] = anomaly_detection_by_payments_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_payments_df['Business_Threshold_2'] = anomaly_detection_by_payments_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_payments_df['Business_Threshold_3'] = anomaly_detection_by_payments_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# Extracting keys from 'transfer_to_accounts_threshold_1_IQR' to create 'user_user_interaction'
anomaly_detection_by_payments_df['user_user_interaction'] = anomaly_detection_by_payments_df['Third_Party_Account_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# Extracting keys from 'industry_threshold_1_IQR' to create 'user_industry_interaction'
anomaly_detection_by_payments_df['user_business_interaction'] = anomaly_detection_by_payments_df['Business_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# %%
anomaly_detection_by_payments_df
# Out:
#                0.25     0.5    0.75    IQR  Overall_Threshold_1_IQR  \
# Account No
# 101531259.0  1542.5  1542.5  1542.5    0.0                2056.1525
# 104832000.0  1675.0  1675.0  1675.0    0.0                2232.7750
# 105375973.0   900.0   900.0   900.0    0.0                1199.7000
# 106601471.0  1675.0  1675.0  1675.0    0.0                2232.7750
# 108481285.0   640.0   640.0  1584.0  944.0                3000.0000
# ...             ...     ...     ...    ...                      ...
# 995615876.0  1733.0  1733.0  1733.0    0.0                2310.0890
# 996042490.0  3750.0  3750.0  3750.0    0.0                4998.7500
# 998390769.0  1625.0  1625.0  1625.0    0.0                2166.1250
# 998405607.0   450.0   450.0   450.0    0.0                 599.8500
# 999752672.0  2708.0  2708.0  2708.0    0.0                3609.7640
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 101531259.0                2571.3475                   3085.0
# 104832000.0                2792.2250                   3350.0
# 105375973.0                1500.3000                   1800.0
# 106601471.0                2792.2250                   3350.0
# 108481285.0                4416.0000                   6304.0
# ...                              ...                      ...
# 995615876.0                2888.9110                   3466.0
# 996042490.0                6251.2500                   7500.0
# 998390769.0                2708.8750                   3250.0
# 998405607.0                 750.1500                    900.0
# 999752672.0                4514.2360                   5416.0
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 355.0}            {587923845.0: 452.5}
# 105375973.0            {709632525.0: 900.0}            {709632525.0: 900.0}
# 106601471.0                             NaN                             NaN
# 108481285.0            {913801979.0: 640.0}            {913801979.0: 640.0}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0                             NaN                             NaN
# 998390769.0                             NaN                             NaN
# 998405607.0            {388862238.0: 450.0}            {388862238.0: 450.0}
# 999752672.0                             NaN                             NaN
#
#             Third_Party_Account_Threshold_3         Business_Threshold_1  \
# Account No
# 101531259.0                             NaN       {'Hobbycraft': 1542.5}
# 104832000.0            {587923845.0: 582.5}     {'A Yarn Story': 1675.0}
# 105375973.0            {709632525.0: 900.0}                          NaN
# 106601471.0                             NaN       {'Hobbycraft': 1675.0}
# 108481285.0            {913801979.0: 640.0}  {'Happy Days Home': 1584.0}
# ...                                     ...                          ...
# 995615876.0                             NaN          {'Matalan': 1733.0}
# 996042490.0                             NaN  {'Lloyds Pharmacy': 3750.0}
# 998390769.0                             NaN       {'Kings Arms': 1625.0}
# 998405607.0            {388862238.0: 450.0}                          NaN
# 999752672.0                             NaN              {'CPA': 2708.0}
#
#                     Business_Threshold_2         Business_Threshold_3  \
# Account No
# 101531259.0       {'Hobbycraft': 1542.5}       {'Hobbycraft': 1542.5}
# 104832000.0     {'A Yarn Story': 1675.0}     {'A Yarn Story': 1675.0}
# 105375973.0                          NaN                          NaN
# 106601471.0       {'Hobbycraft': 1675.0}       {'Hobbycraft': 1675.0}
# 108481285.0  {'Happy Days Home': 1584.0}  {'Happy Days Home': 1584.0}
# ...                                  ...                          ...
# 995615876.0          {'Matalan': 1733.0}          {'Matalan': 1733.0}
# 996042490.0  {'Lloyds Pharmacy': 3750.0}  {'Lloyds Pharmacy': 3750.0}
# 998390769.0       {'Kings Arms': 1625.0}       {'Kings Arms': 1625.0}
# 998405607.0                          NaN                          NaN
# 999752672.0              {'CPA': 2708.0}              {'CPA': 2708.0}
#
#             user_user_interaction user_business_interaction
# Account No
# 101531259.0                  None              [Hobbycraft]
# 104832000.0         [587923845.0]            [A Yarn Story]
# 105375973.0         [709632525.0]                      None
# 106601471.0                  None              [Hobbycraft]
# 108481285.0         [913801979.0]         [Happy Days Home]
# ...                           ...                       ...
# 995615876.0                  None                 [Matalan]
# 996042490.0                  None         [Lloyds Pharmacy]
# 998390769.0                  None              [Kings Arms]
# 998405607.0         [388862238.0]                      None
# 999752672.0                  None                     [CPA]
#
# [876 rows x 15 columns]

# %% [markdown]
# ## Risk flagging function- per user transaction

# %%
testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
# [22920 rows x 8 columns]

# %%
def get_threshold_value(user_data, key, identifier=None):
    """
    Retrieves threshold values for different risk levels from the user's data.
    If the threshold value for a specific key is a dictionary, it returns the threshold
    for the specified identifier. If no identifier-specific threshold is found,
    it returns a high default threshold.
    """
    value = user_data.get(key, 0)
    return value if not isinstance(value, dict) else value.get(identifier, float('inf'))

def assess_transaction_risk(account_no, amount, third_party_account_no, third_party_name, anomaly_detection_by_expenditures_df, anomaly_detection_by_payments_df):
    if amount >= 0:
        anomaly_detection_df = anomaly_detection_by_payments_df
    else:
        anomaly_detection_df = anomaly_detection_by_expenditures_df
    
    amount = abs(amount)  # Working with the absolute value for comparison
    user_data = anomaly_detection_df.loc[account_no].to_dict() if account_no in anomaly_detection_df.index else {}

    user_user_interaction = user_data.get('user_user_interaction') or []
    user_business_interaction = user_data.get('user_business_interaction') or []

    use_overall_thresholds = True  # Assume we need to use overall thresholds by default
    thresholds = []

    # Check for third-party account interactions
    if third_party_account_no in user_user_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_1', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_2', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_3', third_party_account_no)
        ]
        use_overall_thresholds = thresholds[0] == thresholds[1] == thresholds[2]
    
    # Check for business interactions
    if not use_overall_thresholds and third_party_name in user_business_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Business_Threshold_1', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_2', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_3', third_party_name)
        ]
        use_overall_thresholds = thresholds[0] == thresholds[1] == thresholds[2]

    # Use overall thresholds if necessary
    if use_overall_thresholds or not thresholds:
        thresholds = [
            user_data.get('Overall_Threshold_1_IQR', float('inf')),
            user_data.get('Overall_Threshold_2_IQR', float('inf')),
            user_data.get('Overall_Threshold_3_IQR', float('inf'))
        ]

    # Determine the risk level based on the thresholds
    risk_level = "No Risk"
    if amount > thresholds[2]:
        risk_level = "High Risk"
    elif amount > thresholds[1]:
        risk_level = "Medium Risk"
    elif amount > thresholds[0]:
        risk_level = "Low Risk"

    # Adjust the risk level based on absolute amount thresholds
    if amount <= 15:
        risk_level = "No Risk"
    elif amount <= 50:
        risk_level = "Low Risk" if risk_level != "No Risk" else "No Risk"
    elif amount <= 100:
        risk_level = "Medium Risk" if risk_level == "High Risk" else risk_level

    return risk_level

# %%
testing_transactions['risk_level'] = [
    assess_transaction_risk(
        row['Account No'], row['Amount'], row.get('Third Party Account No'), row.get('Third Party Name'),
        anomaly_detection_by_expenditures_df, anomaly_detection_by_payments_df
    ) for _, row in testing_transactions.iterrows()
]


testing_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime  \
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
#        risk_level
# 50365     No Risk
# 50317    Low Risk
# 156768    No Risk
# 198076    No Risk
# 46751     No Risk
# ...           ...
# 146741    No Risk
# 99244     No Risk
# 165435    No Risk
# 125773    No Risk
# 203041    No Risk
#
# [22920 rows x 9 columns]

# %%
risk_level_counts = testing_transactions['risk_level'].value_counts()
print(risk_level_counts)
# Out:
# No Risk        21127
# High Risk        767
# Low Risk         674
# Medium Risk      352
# Name: risk_level, dtype: int64

# %%
# Filter for Low Risk transactions
low_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'Low Risk']

# Filter for Medium Risk transactions
medium_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'Medium Risk']

# Filter for High Risk transactions
high_risk_transactions = testing_transactions[testing_transactions['risk_level'] == 'High Risk']

# %%
low_risk_transactions
# Out:
#               Date Timestamp   Account No      Balance  Amount  \
# 50317   14/03/2023  17:28:00  419550103.0  6544.593463 -125.30
# 213511  18/11/2023  14:33:00  461990622.0  7706.059671 -271.60
# 46540   05/03/2023  12:42:00  540159353.0  5567.435219 -136.47
# 19700   30/01/2023  08:53:00  687135796.0   762.309887  -95.92
# 35360   20/02/2023  10:15:00  405416860.0  1104.003305 -288.84
# ...            ...       ...          ...          ...     ...
# 162100  04/09/2023  14:23:00  461029994.0  6352.967082 -175.64
# 83056   07/05/2023  10:59:00  169006407.0  8712.088738  -98.08
# 37644   26/02/2023  13:11:00  254853117.0  1796.504230 -284.32
# 126994  18/07/2023  18:35:00  769311479.0  5724.911441 -132.76
# 36460   23/02/2023  11:15:00  547010927.0  3979.447021 -119.50
#
#         Third Party Account No Third Party Name             Datetime  \
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 213511                     NaN          Topshop  2023-11-18 14:33:00
# 46540                      NaN          Matalan  2023-03-05 12:42:00
# 19700                      NaN            Tesco  2023-01-30 08:53:00
# 35360                      NaN            Tesco  2023-02-20 10:15:00
# ...                        ...              ...                  ...
# 162100                     NaN         Fat Face  2023-09-04 14:23:00
# 83056                      NaN    Sports Direct  2023-05-07 10:59:00
# 37644                      NaN            Tesco  2023-02-26 13:11:00
# 126994                     NaN        Sainsbury  2023-07-18 18:35:00
# 36460                      NaN         Fat Face  2023-02-23 11:15:00
#
#        risk_level
# 50317    Low Risk
# 213511   Low Risk
# 46540    Low Risk
# 19700    Low Risk
# 35360    Low Risk
# ...           ...
# 162100   Low Risk
# 83056    Low Risk
# 37644    Low Risk
# 126994   Low Risk
# 36460    Low Risk
#
# [674 rows x 9 columns]

# %%
medium_risk_transactions
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 175960  30/09/2023  10:48:00  930277104.0  11141.312949 -235.20
# 51717   18/03/2023  13:08:00  196289502.0   3840.593098 -127.99
# 13669   16/01/2023  15:28:00  993039226.0   -809.931150 -149.00
# 40104   01/03/2023  00:00:00  742223719.0   2194.509964 -479.00
# 40534   01/03/2023  00:00:00  403383649.0   1696.864120 -471.00
# ...            ...       ...          ...           ...     ...
# 134315  01/08/2023  00:00:00  475277431.0    779.088137 -632.00
# 141250  05/08/2023  12:56:00  987163717.0   5149.073750 -321.30
# 71895   24/04/2023  10:49:00  853907490.0   4575.577850 -184.77
# 153985  30/08/2023  23:59:00  352899149.0   1178.139700 -400.00
# 15606   21/01/2023  06:02:00  108931112.0   -269.056000 -260.00
#
#         Third Party Account No Third Party Name             Datetime  \
# 175960                     NaN         Fat Face  2023-09-30 10:48:00
# 51717                      NaN    Sports Direct  2023-03-18 13:08:00
# 13669                      NaN          Matalan  2023-01-16 15:28:00
# 40104                      NaN          Halifax  2023-03-01 00:00:00
# 40534                      NaN          Halifax  2023-03-01 00:00:00
# ...                        ...              ...                  ...
# 134315                     NaN              LBG  2023-08-01 00:00:00
# 141250                     NaN    Fitted Stitch  2023-08-05 12:56:00
# 71895                      NaN         Fat Face  2023-04-24 10:49:00
# 153985             119943495.0              NaN  2023-08-30 23:59:00
# 15606                      NaN         Gap Kids  2023-01-21 06:02:00
#
#          risk_level
# 175960  Medium Risk
# 51717   Medium Risk
# 13669   Medium Risk
# 40104   Medium Risk
# 40534   Medium Risk
# ...             ...
# 134315  Medium Risk
# 141250  Medium Risk
# 71895   Medium Risk
# 153985  Medium Risk
# 15606   Medium Risk
#
# [352 rows x 9 columns]

# %%
high_risk_transactions
# Out:
#               Date Timestamp   Account No      Balance   Amount  \
# 75970   01/05/2023  00:00:00  524425303.0   459.831200  -917.00
# 199128  01/11/2023  00:00:00  846550094.0  1974.794772 -1170.00
# 150158  23/08/2023  12:29:00  749378808.0  4224.142300  -201.59
# 177042  01/10/2023  00:00:00  524425303.0   107.475500  -917.00
# 155671  01/09/2023  00:00:00  146686559.0  -331.699811 -1301.00
# ...            ...       ...          ...          ...      ...
# 94509   01/06/2023  00:00:00  873693307.0  6958.997521  -967.00
# 94735   01/06/2023  00:00:00  920830317.0   403.464421 -1361.00
# 21698   31/01/2023  23:59:00  255814263.0  3596.472341 -1200.00
# 199336  01/11/2023  00:00:00  119993184.0 -2027.144403 -1223.00
# 199136  01/11/2023  00:00:00  851181128.0  5696.625741  -448.00
#
#         Third Party Account No Third Party Name             Datetime  \
# 75970                      NaN              LBG  2023-05-01 00:00:00
# 199128                     NaN          Halifax  2023-11-01 00:00:00
# 150158                     NaN          Topshop  2023-08-23 12:29:00
# 177042                     NaN              LBG  2023-10-01 00:00:00
# 155671                     NaN          Halifax  2023-09-01 00:00:00
# ...                        ...              ...                  ...
# 94509                      NaN              LBG  2023-06-01 00:00:00
# 94735                      NaN              LBG  2023-06-01 00:00:00
# 21698              117308635.0              NaN  2023-01-31 23:59:00
# 199336                     NaN              LBG  2023-11-01 00:00:00
# 199136                     NaN              LBG  2023-11-01 00:00:00
#
#        risk_level
# 75970   High Risk
# 199128  High Risk
# 150158  High Risk
# 177042  High Risk
# 155671  High Risk
# ...           ...
# 94509   High Risk
# 94735   High Risk
# 21698   High Risk
# 199336  High Risk
# 199136  High Risk
#
# [767 rows x 9 columns]

# %%
account = anomaly_detection_by_payments_df[anomaly_detection_by_payments_df.index == 817294757.0]
account
# Out:
#                0.25     0.5    0.75  IQR  Overall_Threshold_1_IQR  \
# Account No
# 817294757.0  1842.5  1842.5  1842.5  0.0                2456.0525
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 817294757.0                3071.4475                   3685.0
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 817294757.0            {254018059.0: 105.0}            {254018059.0: 127.5}
#
#             Third_Party_Account_Threshold_3 Business_Threshold_1  \
# Account No
# 817294757.0            {254018059.0: 157.5}  {'Jollyes': 1842.5}
#
#             Business_Threshold_2 Business_Threshold_3 user_user_interaction  \
# Account No
# 817294757.0  {'Jollyes': 1842.5}  {'Jollyes': 1842.5}         [254018059.0]
#
#             user_business_interaction
# Account No
# 817294757.0                 [Jollyes]

# %%
account = anomaly_detection_by_payments_df[anomaly_detection_by_payments_df.index == 817294757.0]
account
# Out:
#                0.25     0.5    0.75  IQR  Overall_Threshold_1_IQR  \
# Account No
# 817294757.0  1842.5  1842.5  1842.5  0.0                2456.0525
#
#              Overall_Threshold_2_IQR  Overall_Threshold_3_IQR  \
# Account No
# 817294757.0                3071.4475                   3685.0
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 817294757.0            {254018059.0: 105.0}            {254018059.0: 127.5}
#
#             Third_Party_Account_Threshold_3 Business_Threshold_1  \
# Account No
# 817294757.0            {254018059.0: 157.5}  {'Jollyes': 1842.5}
#
#             Business_Threshold_2 Business_Threshold_3 user_user_interaction  \
# Account No
# 817294757.0  {'Jollyes': 1842.5}  {'Jollyes': 1842.5}         [254018059.0]
#
#             user_business_interaction
# Account No
# 817294757.0                 [Jollyes]

# %%
risk_level_counts = pd.Series({
    "Low Risk": low_risk_transactions.shape[0],
    "Medium Risk": medium_risk_transactions.shape[0],  
    "High Risk": high_risk_transactions.shape[0],    
})

# Plotting
risk_level_counts.plot(kind='bar', figsize=(8, 4), color=['green', 'orange', 'red', 'blue'])
plt.title('Transaction Counts by Risk Level')
plt.xlabel('Risk Level')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This is out of the testing set of 22920.

# %%
# Create figure and subplots
fig, axs = plt.subplots(3, 2, figsize=(19, 20))

# Third-Party Name Frequency Visualisation for Low Risk Transactions
third_party_counts = low_risk_transactions['Third Party Name'].value_counts()
third_party_counts.plot(kind='bar', ax=axs[0, 0], color='green')
axs[0, 0].set_title('Frequency of Transactions by Third-Party Name for Low Risk Transactions')
axs[0, 0].set_xlabel('Third Party Name')
axs[0, 0].set_ylabel('Number of Transactions')
axs[0, 0].tick_params(axis='x', rotation=45)

# Histogram for Transaction Amounts for Low Risk Transactions
axs[0, 1].hist(low_risk_transactions['Amount'], bins=15, color='green', edgecolor='black')
axs[0, 1].set_title('Distribution of Transaction Amounts for Low Risk Transactions')
axs[0, 1].set_xlabel('Transaction Amount')
axs[0, 1].set_ylabel('Frequency')
axs[0, 1].grid(axis='y', alpha=0.75)

# Third-Party Name Frequency Visualisation for Medium Risk Transactions
medium_third_party_counts = medium_risk_transactions['Third Party Name'].value_counts()
medium_third_party_counts.plot(kind='bar', ax=axs[1, 0], color='orange')
axs[1, 0].set_title('Frequency of Transactions by Third-Party Name for Medium Risk Transactions')
axs[1, 0].set_xlabel('Third Party Name')
axs[1, 0].set_ylabel('Number of Transactions')
axs[1, 0].tick_params(axis='x', rotation=45)

# Histogram for Transaction Amounts for Medium Risk Transactions
axs[1, 1].hist(medium_risk_transactions['Amount'], bins=10, color='orange', edgecolor='black')
axs[1, 1].set_title('Distribution of Transaction Amounts for Medium Risk Transactions')
axs[1, 1].set_xlabel('Transaction Amount')
axs[1, 1].set_ylabel('Frequency')

# Third-Party Name Frequency Visualisation for High Risk Transactions
high_third_party_counts = high_risk_transactions['Third Party Name'].value_counts()
high_third_party_counts.plot(kind='bar', ax=axs[2, 0], color='red')
axs[2, 0].set_title('Frequency of Transactions by Third-Party Name for High Risk Transactions')
axs[2, 0].set_xlabel('Third Party Name')
axs[2, 0].set_ylabel('Number of Transactions')
axs[2, 0].tick_params(axis='x', rotation=45)

# Histogram for Transaction Amounts for High Risk Transactions
axs[2, 1].hist(high_risk_transactions['Amount'], bins=10, color='red', edgecolor='black')
axs[2, 1].set_title('Distribution of Transaction Amounts for High Risk Transactions')
axs[2, 1].set_xlabel('Transaction Amount')
axs[2, 1].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Anomaly detection using standard deviations for the thresholds

# %%
payments_training_std_df = training_transactions_copy[training_transactions_copy['Amount'] > 0]
expenditures_training_std_df = training_transactions_copy[training_transactions_copy['Amount'] < 0]

# %%
# Taking the absolute values of the amount column
expenditures_training_std_df["Amount"] = expenditures_training_std_df["Amount"].abs()

expenditures_training_std_df
# Out:
# /var/folders/rw/215myrns4md_n1k8nkyww6mw0000gn/T/ipykernel_70074/4160095559.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   expenditures_training_std_df["Amount"] = expenditures_training_std_df["Amount"].abs()
#               Date Timestamp   Account No       Balance  Amount  \
# 215690  22/11/2023  18:12:00  496674181.0  -2187.525472  111.38
# 20958   31/01/2023  10:05:00  421881811.0   2363.284100   22.00
# 197261  30/10/2023  20:06:00  387957305.0  -2677.341106   37.99
# 63359   03/04/2023  08:51:00  120634201.0   1441.908700   41.04
# 6331    02/01/2023  18:47:00  713910252.0   2116.752100  140.49
# ...            ...       ...          ...           ...     ...
# 206083  05/11/2023  07:55:00  550169791.0  22875.430900   45.04
# 36482   23/02/2023  12:38:00  554792076.0   2248.810443   75.74
# 40177   01/03/2023  00:00:00  624563756.0    -14.727071  822.00
# 150781  24/08/2023  20:15:00  176922958.0   1440.312330   37.43
# 210763  13/11/2023  10:23:00  749378808.0   4130.408178  138.56
#
#         Third Party Account No Third Party Name             Datetime
# 215690                     NaN       Coop Local  2023-11-22 18:12:00
# 20958                      NaN    Sports Direct  2023-01-31 10:05:00
# 197261                     NaN            Tesco  2023-10-30 20:06:00
# 63359                      NaN            Tesco  2023-04-03 08:51:00
# 6331                       NaN            Tesco  2023-01-02 18:47:00
# ...                        ...              ...                  ...
# 206083                     NaN             Etsy  2023-11-05 07:55:00
# 36482                      NaN          Topshop  2023-02-23 12:38:00
# 40177                      NaN              LBG  2023-03-01 00:00:00
# 150781                     NaN        Deliveroo  2023-08-24 20:15:00
# 210763                     NaN         Fat Face  2023-11-13 10:23:00
#
# [196934 rows x 8 columns]

# %% [markdown]
# ### Creating anomaly detection dataframe: expenditures

# %%
# Calculate the mean and standard deviation for each account
mean_std = expenditures_training_std_df.groupby('Account No')['Amount'].agg(['mean', 'std'])

# Establishing initial thresholds based on standard deviations from the mean
mean_std['Threshold_1_STD'] = mean_std['mean'] + mean_std['std'] * 1  # 1 std from the mean
mean_std['Threshold_2_STD'] = mean_std['mean'] + mean_std['std'] * 2  # 2 stds from the mean
mean_std['Threshold_3_STD'] = mean_std['mean'] + mean_std['std'] * 3  # 3 stds from the mean

# Define the specific percentage increments for adjusting thresholds if they are equal
percent_increment_1 = 0.333
percent_increment_2 = 0.667
percent_increment_3 = 1  

# Function to apply increments if thresholds are equal
def apply_specific_increments_if_equal(row):
    # Check if the three initially calculated thresholds are equal
    if row['Threshold_1_STD'] == row['Threshold_2_STD'] == row['Threshold_3_STD']:
        # The mean and standard deviation
        mean_value = row['mean']
        # Apply specific increments
        row['Threshold_1_STD'] = mean_value * (1 + percent_increment_1)
        row['Threshold_2_STD'] = mean_value * (1 + percent_increment_2)
        row['Threshold_3_STD'] = mean_value * (1 + percent_increment_3)
    return row

# Apply the specific increment logic to each account if thresholds are initially equal
anomaly_detection_by_expenditures_std_df = mean_std.apply(apply_specific_increments_if_equal, axis=1)

# Renaming the index to 'Account No' for clarity
anomaly_detection_by_expenditures_std_df.index.rename('Account No', inplace=True)

# Displaying the first few rows to verify the adjustments
anomaly_detection_by_expenditures_std_df.head()
# Out:
#                    mean         std  Threshold_1_STD  Threshold_2_STD  \
# Account No
# 101531259.0  159.948152  251.152031       411.100183       662.252215
# 104832000.0  174.883897  271.322803       446.206700       717.529503
# 105375973.0   68.679481   63.704193       132.383675       196.087868
# 106601471.0   41.950710   52.952844        94.903554       147.856398
# 108481285.0   44.073849  138.594780       182.668628       321.263408
#
#              Threshold_3_STD
# Account No
# 101531259.0       913.404246
# 104832000.0       988.852306
# 105375973.0       259.792061
# 106601471.0       200.809242
# 108481285.0       459.858188

# %%
def calculate_thresholds_sd(group, multiplier):
    mean = group['Amount'].mean()
    std_dev = group['Amount'].std()
    threshold = mean + (multiplier * std_dev)
    return threshold

# %%
# For Threshold 1 (1 * Standard Deviation)
thresholds_1 = expenditures_training_std_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 1)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_1']))).to_dict()

# For Threshold 2 (2 * Standard Deviation)
thresholds_2 = expenditures_training_std_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 2)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_2']))).to_dict()

# For Threshold 3 (3 * Standard Deviation)
thresholds_3 = expenditures_training_std_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 3)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_3']))).to_dict()

# %%
anomaly_detection_by_expenditures_std_df['Business_Threshold_1'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Business_Threshold_2'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Business_Threshold_3'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# For Threshold 1 (1 * Standard Deviation)
thresholds_1 = expenditures_training_std_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 1)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_1']))).to_dict()

# For Threshold 2 (2 * Standard Deviation)
thresholds_2 = expenditures_training_std_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 2)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_2']))).to_dict()

# For Threshold 3 (3 * Standard Deviation)
thresholds_3 = expenditures_training_std_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_3']))).to_dict()

# %%
anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_1'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_2'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_3'] = anomaly_detection_by_expenditures_std_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# Extracting keys from 'Business_Threshold_1' to create 'user_business_interaction'
anomaly_detection_by_expenditures_std_df['user_business_interaction'] = anomaly_detection_by_expenditures_std_df['Business_Threshold_1'].apply(
    lambda x: [key for key, value in x.items() if not np.isnan(value)] if isinstance(x, dict) else None
)


anomaly_detection_by_expenditures_std_df['user_user_interaction'] = anomaly_detection_by_expenditures_std_df['Third_Party_Account_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# %% [markdown]
# ### Creating anomaly detection dataframe: expenditures: Payments

# %%
# Calculate the mean and standard deviation for each account
mean_std = payments_training_std_df.groupby('Account No')['Amount'].agg(['mean', 'std'])

# Establishing initial thresholds based on standard deviations from the mean
mean_std['Threshold_1_STD'] = mean_std['mean'] + mean_std['std'] * 1  # 1 std from the mean
mean_std['Threshold_2_STD'] = mean_std['mean'] + mean_std['std'] * 2  # 2 stds from the mean
mean_std['Threshold_3_STD'] = mean_std['mean'] + mean_std['std'] * 3  # 3 stds from the mean

# Define the specific percentage increments for adjusting thresholds if they are equal
percent_increment_1 = 0.333
percent_increment_2 = 0.667
percent_increment_3 = 1  

# Function to apply increments if thresholds are equal
def apply_specific_increments_if_equal(row):
    # Check if the three initially calculated thresholds are equal
    if row['Threshold_1_STD'] == row['Threshold_2_STD'] == row['Threshold_3_STD']:
        # The mean and standard deviation
        mean_value = row['mean']
        # Apply specific increments
        row['Threshold_1_STD'] = mean_value * (1 + percent_increment_1)
        row['Threshold_2_STD'] = mean_value * (1 + percent_increment_2)
        row['Threshold_3_STD'] = mean_value * (1 + percent_increment_3)
    return row

# Apply the specific increment logic to each account if thresholds are initially equal
anomaly_detection_by_payments_std_df = mean_std.apply(apply_specific_increments_if_equal, axis=1)

# Renaming the index to 'Account No' for clarity
anomaly_detection_by_payments_std_df.index.rename('Account No', inplace=True)

# Displaying the first few rows to verify the adjustments
anomaly_detection_by_payments_std_df
# Out:
#                     mean         std  Threshold_1_STD  Threshold_2_STD  \
# Account No
# 101531259.0  1542.500000    0.000000      2056.152500      2571.347500
# 104832000.0  1411.363636  587.273748      1998.637384      2585.911131
# 105375973.0   900.000000    0.000000      1199.700000      1500.300000
# 106601471.0  1675.000000    0.000000      2232.775000      2792.225000
# 108481285.0  1064.800000  481.834390      1546.634390      2028.468779
# ...                  ...         ...              ...              ...
# 995615876.0  1733.000000    0.000000      2310.089000      2888.911000
# 996042490.0  3750.000000    0.000000      4998.750000      6251.250000
# 998390769.0  1625.000000    0.000000      2166.125000      2708.875000
# 998405607.0   530.769231  252.139562       782.908793      1035.048356
# 999752672.0  2708.000000    0.000000      3609.764000      4514.236000
#
#              Threshold_3_STD
# Account No
# 101531259.0      3085.000000
# 104832000.0      3173.184879
# 105375973.0      1800.000000
# 106601471.0      3350.000000
# 108481285.0      2510.303169
# ...                      ...
# 995615876.0      3466.000000
# 996042490.0      7500.000000
# 998390769.0      3250.000000
# 998405607.0      1287.187918
# 999752672.0      5416.000000
#
# [876 rows x 5 columns]

# %%
# For Threshold 1 (1 * Standard Deviation)
thresholds_1 = payments_training_std_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 1)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_1']))).to_dict()

# For Threshold 2 (2 * Standard Deviation)
thresholds_2 = payments_training_std_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 2)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_2']))).to_dict()

# For Threshold 3 (3 * Standard Deviation)
thresholds_3 = payments_training_std_df.dropna(subset=['Account No', 'Third Party Name']).groupby(['Account No', 'Third Party Name']).apply(lambda group: calculate_thresholds_sd(group, 3)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Name'], x['Threshold_3']))).to_dict()

# %%
anomaly_detection_by_payments_std_df['Business_Threshold_1'] = anomaly_detection_by_payments_std_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_payments_std_df['Business_Threshold_2'] = anomaly_detection_by_payments_std_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_payments_std_df['Business_Threshold_3'] = anomaly_detection_by_payments_std_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# For Threshold 1 (1 * Standard Deviation)
thresholds_1 = payments_training_std_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 1)).reset_index(name='Threshold_1')
thresholds_structured_1 = thresholds_1.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_1']))).to_dict()

# For Threshold 2 (2 * Standard Deviation)
thresholds_2 = payments_training_std_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 2)).reset_index(name='Threshold_2')
thresholds_structured_2 = thresholds_2.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_2']))).to_dict()

# For Threshold 3 (3 * Standard Deviation)
thresholds_3 = payments_training_std_df.dropna(subset=['Account No', 'Third Party Account No']).groupby(['Account No', 'Third Party Account No']).apply(lambda group: calculate_thresholds(group, 3)).reset_index(name='Threshold_3')
thresholds_structured_3 = thresholds_3.groupby('Account No').apply(lambda x: dict(zip(x['Third Party Account No'], x['Threshold_3']))).to_dict()

# %%
anomaly_detection_by_payments_std_df['Third_Party_Account_Threshold_1'] = anomaly_detection_by_payments_std_df.index.map(lambda x: thresholds_structured_1.get(x, np.nan))
anomaly_detection_by_payments_std_df['Third_Party_Account_Threshold_2'] = anomaly_detection_by_payments_std_df.index.map(lambda x: thresholds_structured_2.get(x, np.nan))
anomaly_detection_by_payments_std_df['Third_Party_Account_Threshold_3'] = anomaly_detection_by_payments_std_df.index.map(lambda x: thresholds_structured_3.get(x, np.nan))

# %%
# Extracting keys from 'Business_Threshold_1' to create 'user_business_interaction'
anomaly_detection_by_payments_std_df['user_business_interaction'] = anomaly_detection_by_payments_std_df['Business_Threshold_1'].apply(
    lambda x: [key for key, value in x.items() if not np.isnan(value)] if isinstance(x, dict) else None
)


anomaly_detection_by_payments_std_df['user_user_interaction'] = anomaly_detection_by_payments_std_df['Third_Party_Account_Threshold_1'].apply(lambda x: list(x.keys()) if isinstance(x, dict) else None)

# %%
anomaly_detection_by_payments_std_df
# Out:
#                     mean         std  Threshold_1_STD  Threshold_2_STD  \
# Account No
# 101531259.0  1542.500000    0.000000      2056.152500      2571.347500
# 104832000.0  1411.363636  587.273748      1998.637384      2585.911131
# 105375973.0   900.000000    0.000000      1199.700000      1500.300000
# 106601471.0  1675.000000    0.000000      2232.775000      2792.225000
# 108481285.0  1064.800000  481.834390      1546.634390      2028.468779
# ...                  ...         ...              ...              ...
# 995615876.0  1733.000000    0.000000      2310.089000      2888.911000
# 996042490.0  3750.000000    0.000000      4998.750000      6251.250000
# 998390769.0  1625.000000    0.000000      2166.125000      2708.875000
# 998405607.0   530.769231  252.139562       782.908793      1035.048356
# 999752672.0  2708.000000    0.000000      3609.764000      4514.236000
#
#              Threshold_3_STD         Business_Threshold_1  \
# Account No
# 101531259.0      3085.000000       {'Hobbycraft': 1542.5}
# 104832000.0      3173.184879     {'A Yarn Story': 1675.0}
# 105375973.0      1800.000000                          NaN
# 106601471.0      3350.000000       {'Hobbycraft': 1675.0}
# 108481285.0      2510.303169  {'Happy Days Home': 1584.0}
# ...                      ...                          ...
# 995615876.0      3466.000000          {'Matalan': 1733.0}
# 996042490.0      7500.000000  {'Lloyds Pharmacy': 3750.0}
# 998390769.0      3250.000000       {'Kings Arms': 1625.0}
# 998405607.0      1287.187918                          NaN
# 999752672.0      5416.000000              {'CPA': 2708.0}
#
#                     Business_Threshold_2         Business_Threshold_3  \
# Account No
# 101531259.0       {'Hobbycraft': 1542.5}       {'Hobbycraft': 1542.5}
# 104832000.0     {'A Yarn Story': 1675.0}     {'A Yarn Story': 1675.0}
# 105375973.0                          NaN                          NaN
# 106601471.0       {'Hobbycraft': 1675.0}       {'Hobbycraft': 1675.0}
# 108481285.0  {'Happy Days Home': 1584.0}  {'Happy Days Home': 1584.0}
# ...                                  ...                          ...
# 995615876.0          {'Matalan': 1733.0}          {'Matalan': 1733.0}
# 996042490.0  {'Lloyds Pharmacy': 3750.0}  {'Lloyds Pharmacy': 3750.0}
# 998390769.0       {'Kings Arms': 1625.0}       {'Kings Arms': 1625.0}
# 998405607.0                          NaN                          NaN
# 999752672.0              {'CPA': 2708.0}              {'CPA': 2708.0}
#
#             Third_Party_Account_Threshold_1 Third_Party_Account_Threshold_2  \
# Account No
# 101531259.0                             NaN                             NaN
# 104832000.0            {587923845.0: 322.5}            {587923845.0: 387.5}
# 105375973.0            {709632525.0: 900.0}            {709632525.0: 900.0}
# 106601471.0                             NaN                             NaN
# 108481285.0            {913801979.0: 640.0}            {913801979.0: 640.0}
# ...                                     ...                             ...
# 995615876.0                             NaN                             NaN
# 996042490.0                             NaN                             NaN
# 998390769.0                             NaN                             NaN
# 998405607.0            {388862238.0: 450.0}            {388862238.0: 450.0}
# 999752672.0                             NaN                             NaN
#
#             Third_Party_Account_Threshold_3 user_business_interaction  \
# Account No
# 101531259.0                             NaN              [Hobbycraft]
# 104832000.0            {587923845.0: 452.5}            [A Yarn Story]
# 105375973.0            {709632525.0: 900.0}                      None
# 106601471.0                             NaN              [Hobbycraft]
# 108481285.0            {913801979.0: 640.0}         [Happy Days Home]
# ...                                     ...                       ...
# 995615876.0                             NaN                 [Matalan]
# 996042490.0                             NaN         [Lloyds Pharmacy]
# 998390769.0                             NaN              [Kings Arms]
# 998405607.0            {388862238.0: 450.0}                      None
# 999752672.0                             NaN                     [CPA]
#
#             user_user_interaction
# Account No
# 101531259.0                  None
# 104832000.0         [587923845.0]
# 105375973.0         [709632525.0]
# 106601471.0                  None
# 108481285.0         [913801979.0]
# ...                           ...
# 995615876.0                  None
# 996042490.0                  None
# 998390769.0                  None
# 998405607.0         [388862238.0]
# 999752672.0                  None
#
# [876 rows x 13 columns]

# %%
def assess_transaction_risk_std(account_no, amount, third_party_account_no, third_party_name, anomaly_detection_by_expenditures_std_df, anomaly_detection_by_payments_std_df):
    if amount >= 0:
        anomaly_detection_df = anomaly_detection_by_payments_std_df
    else:
        anomaly_detection_df = anomaly_detection_by_expenditures_std_df
    
    # Convert the amount to positive for comparison
    amount = abs(amount)
    risk_level = "No Risk"
    user_data = anomaly_detection_df.loc[account_no].to_dict()

    
    amount = abs(amount)  # Working with the absolute value for comparison
    user_data = anomaly_detection_df.loc[account_no].to_dict() if account_no in anomaly_detection_df.index else {}

    user_user_interaction = user_data.get('user_user_interaction') or []
    user_business_interaction = user_data.get('user_business_interaction') or []

    use_overall_thresholds = True  # Assume we need to use overall thresholds by default
    thresholds = []
    
    # Check for third-party account interactions
    if third_party_account_no in user_user_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_1', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_2', third_party_account_no),
            get_threshold_value(user_data, 'Third_Party_Account_Threshold_3', third_party_account_no)
        ]
        use_overall_thresholds = thresholds[0] == thresholds[1] == thresholds[2]
    
    # Check for business interactions
    if not use_overall_thresholds and third_party_name in user_business_interaction:
        thresholds = [
            get_threshold_value(user_data, 'Business_Threshold_1', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_2', third_party_name),
            get_threshold_value(user_data, 'Business_Threshold_3', third_party_name)
        ]
        use_overall_thresholds = thresholds[0] == thresholds[1] == thresholds[2]

    # Use overall thresholds if necessary
    if use_overall_thresholds or not thresholds:
        thresholds = [
            user_data.get('Threshold_1_STD', float('inf')),
            user_data.get('Threshold_2_STD', float('inf')),
            user_data.get('Threshold_3_STD', float('inf'))
        ]
    
    # Determine the risk level based on the thresholds
    risk_level = "No Risk"
    if amount > thresholds[2]:
        risk_level = "High Risk"
    elif amount > thresholds[1]:
        risk_level = "Medium Risk"
    elif amount > thresholds[0]:
        risk_level = "Low Risk"

    # Adjust the risk level based on absolute amount thresholds
    if amount <= 15:
        risk_level = "No Risk"
    elif amount <= 50:
        risk_level = "Low Risk" if risk_level != "No Risk" else "No Risk"
    elif amount <= 100:
        risk_level = "Medium Risk" if risk_level == "High Risk" else risk_level

    return risk_level

# %%
testing_transactions_copy['risk_level'] = [
    assess_transaction_risk_std(
        row['Account No'], row['Amount'], row.get('Third Party Account No'), row.get('Third Party Name'),
        anomaly_detection_by_expenditures_std_df, anomaly_detection_by_payments_std_df
    ) for _, row in testing_transactions.iterrows()
]


testing_transactions_copy
# Out:
#               Date Timestamp   Account No       Balance  Amount  \
# 50365   14/03/2023  18:33:00  712474734.0  -1324.548831  -31.23
# 50317   14/03/2023  17:28:00  419550103.0   6544.593463 -125.30
# 156768  31/08/2023  23:59:00  834581602.0    925.931550   -7.00
# 198076  31/10/2023  09:27:00  250957494.0   1090.427100  -37.99
# 46751   05/03/2023  16:34:00  675231808.0   4038.532728 -158.90
# ...            ...       ...          ...           ...     ...
# 146741  16/08/2023  10:05:00  779946617.0  13089.944442   -4.84
# 99244   02/06/2023  10:01:00  497809732.0   1214.287223   -1.50
# 165435  10/09/2023  17:00:00  146909202.0   4552.412277  -77.00
# 125773  16/07/2023  07:12:00  678330503.0   4077.564304   -1.56
# 203041  31/10/2023  23:59:00  490790931.0    590.227650  -15.99
#
#         Third Party Account No Third Party Name             Datetime  \
# 50365                      NaN        Deliveroo  2023-03-14 18:33:00
# 50317                      NaN   Loosely Fitted  2023-03-14 17:28:00
# 156768                     NaN             Xbox  2023-08-31 23:59:00
# 198076                     NaN    Sports Direct  2023-10-31 09:27:00
# 46751                      NaN       Selfridges  2023-03-05 16:34:00
# ...                        ...              ...                  ...
# 146741                     NaN           AMAZON  2023-08-16 10:05:00
# 99244                      NaN  Five Senses Art  2023-06-02 10:01:00
# 165435                     NaN          Topshop  2023-09-10 17:00:00
# 125773                     NaN           Amazon  2023-07-16 07:12:00
# 203041                     NaN          Netflix  2023-10-31 23:59:00
#
#        risk_level
# 50365     No Risk
# 50317    Low Risk
# 156768    No Risk
# 198076    No Risk
# 46751     No Risk
# ...           ...
# 146741    No Risk
# 99244     No Risk
# 165435    No Risk
# 125773    No Risk
# 203041    No Risk
#
# [22920 rows x 9 columns]

# %%
risk_level_counts_std = testing_transactions_copy['risk_level'].value_counts()
print(risk_level_counts_std)
# Out:
# No Risk        20859
# Low Risk         969
# High Risk        596
# Medium Risk      496
# Name: risk_level, dtype: int64

# %%
# Filter for Low Risk transactions
low_risk_transactions_std = testing_transactions_copy[testing_transactions_copy['risk_level'] == 'Low Risk']

# Filter for Medium Risk transactions
medium_risk_transactions_std = testing_transactions_copy[testing_transactions_copy['risk_level'] == 'Medium Risk']

# Filter for High Risk transactions
high_risk_transactions_std = testing_transactions_copy[testing_transactions_copy['risk_level'] == 'High Risk']

# %%
high_risk_transactions_std
# Out:
#               Date Timestamp   Account No      Balance   Amount  \
# 75970   01/05/2023  00:00:00  524425303.0   459.831200  -917.00
# 199128  01/11/2023  00:00:00  846550094.0  1974.794772 -1170.00
# 13669   16/01/2023  15:28:00  993039226.0  -809.931150  -149.00
# 40104   01/03/2023  00:00:00  742223719.0  2194.509964  -479.00
# 150158  23/08/2023  12:29:00  749378808.0  4224.142300  -201.59
# ...            ...       ...          ...          ...      ...
# 76105   01/05/2023  00:00:00  277562576.0  1362.421406  -856.00
# 865     01/01/2023  00:00:00  576188756.0  1180.000000  -597.00
# 134314  01/08/2023  00:00:00  570269025.0  2327.165269  -488.00
# 94509   01/06/2023  00:00:00  873693307.0  6958.997521  -967.00
# 199336  01/11/2023  00:00:00  119993184.0 -2027.144403 -1223.00
#
#         Third Party Account No Third Party Name             Datetime  \
# 75970                      NaN              LBG  2023-05-01 00:00:00
# 199128                     NaN          Halifax  2023-11-01 00:00:00
# 13669                      NaN          Matalan  2023-01-16 15:28:00
# 40104                      NaN          Halifax  2023-03-01 00:00:00
# 150158                     NaN          Topshop  2023-08-23 12:29:00
# ...                        ...              ...                  ...
# 76105                      NaN          Halifax  2023-05-01 00:00:00
# 865                        NaN              LBG  2023-01-01 00:00:00
# 134314                     NaN              LBG  2023-08-01 00:00:00
# 94509                      NaN              LBG  2023-06-01 00:00:00
# 199336                     NaN              LBG  2023-11-01 00:00:00
#
#        risk_level
# 75970   High Risk
# 199128  High Risk
# 13669   High Risk
# 40104   High Risk
# 150158  High Risk
# ...           ...
# 76105   High Risk
# 865     High Risk
# 134314  High Risk
# 94509   High Risk
# 199336  High Risk
#
# [596 rows x 9 columns]

# %%
risk_level_counts_std = pd.Series({
    "Low Risk": low_risk_transactions_std.shape[0],
    "Medium Risk": medium_risk_transactions_std.shape[0],  
    "High Risk": high_risk_transactions_std.shape[0],    
})

# Plotting
risk_level_counts_std.plot(kind='bar', figsize=(8, 4), color=['green', 'orange', 'red'])
plt.title('Transaction Counts by Risk Level')
plt.xlabel('Risk Level')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=45)
plt.show()

# %%
# Create figure and subplots
fig, axs = plt.subplots(3, 2, figsize=(19, 20))

# Third-Party Name Frequency Visualisation for Low Risk Transactions
third_party_counts = low_risk_transactions_std['Third Party Name'].value_counts()
third_party_counts.plot(kind='bar', ax=axs[0, 0], color='green')
axs[0, 0].set_title('Frequency of Transactions by Third-Party Name for Low Risk Transactions')
axs[0, 0].set_xlabel('Third Party Name')
axs[0, 0].set_ylabel('Number of Transactions')
axs[0, 0].tick_params(axis='x', rotation=45)

# Histogram for Transaction Amounts for Low Risk Transactions
axs[0, 1].hist(low_risk_transactions_std['Amount'], bins=15, color='green', edgecolor='black')
axs[0, 1].set_title('Distribution of Transaction Amounts for Low Risk Transactions')
axs[0, 1].set_xlabel('Transaction Amount')
axs[0, 1].set_ylabel('Frequency')
axs[0, 1].grid(axis='y', alpha=0.75)

# Third-Party Name Frequency Visualisation for Medium Risk Transactions
medium_third_party_counts = medium_risk_transactions_std['Third Party Name'].value_counts()
medium_third_party_counts.plot(kind='bar', ax=axs[1, 0], color='orange')
axs[1, 0].set_title('Frequency of Transactions by Third-Party Name for Medium Risk Transactions')
axs[1, 0].set_xlabel('Third Party Name')
axs[1, 0].set_ylabel('Number of Transactions')
axs[1, 0].tick_params(axis='x', rotation=45)

# Histogram for Transaction Amounts for Medium Risk Transactions
axs[1, 1].hist(medium_risk_transactions_std['Amount'], bins=10, color='orange', edgecolor='black')
axs[1, 1].set_title('Distribution of Transaction Amounts for Medium Risk Transactions')
axs[1, 1].set_xlabel('Transaction Amount')
axs[1, 1].set_ylabel('Frequency')

# Third-Party Name Frequency Visualisation for High Risk Transactions
high_third_party_counts = high_risk_transactions_std['Third Party Name'].value_counts()
high_third_party_counts.plot(kind='bar', ax=axs[2, 0], color='red')
axs[2, 0].set_title('Frequency of Transactions by Third-Party Name for High Risk Transactions')
axs[2, 0].set_xlabel('Third Party Name')
axs[2, 0].set_ylabel('Number of Transactions')
axs[2, 0].tick_params(axis='x', rotation=45)

# Histogram for Transaction Amounts for High Risk Transactions
axs[2, 1].hist(high_risk_transactions_std['Amount'], bins=10, color='red', edgecolor='black')
axs[2, 1].set_title('Distribution of Transaction Amounts for High Risk Transactions')
axs[2, 1].set_xlabel('Transaction Amount')
axs[2, 1].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparing the IQR and STD models

# %%
# Find overlap for low-risk transactions
overlap_low_risk_index = low_risk_transactions.index.intersection(low_risk_transactions_std.index)
# Creating a DataFrame with overlapping indices for low-risk
overlap_low_risk = low_risk_transactions.loc[overlap_low_risk_index]

# Repeat for medium and high-risk transactions
overlap_medium_risk_index = medium_risk_transactions.index.intersection(medium_risk_transactions_std.index)
overlap_medium_risk = medium_risk_transactions.loc[overlap_medium_risk_index]

overlap_high_risk_index = high_risk_transactions.index.intersection(high_risk_transactions_std.index)
overlap_high_risk = high_risk_transactions.loc[overlap_high_risk_index]

# %%
# Assuming the overlaps have already been calculated and we're using the index lists directly
# For illustration, let's create example sets for each risk level
low_risk_transactions_set = set(low_risk_transactions.index)
low_risk_transactions_std_set = set(low_risk_transactions_std.index)

medium_risk_transactions_set = set(medium_risk_transactions.index)
medium_risk_transactions_std_set = set(medium_risk_transactions_std.index)

high_risk_transactions_set = set(high_risk_transactions.index)
high_risk_transactions_std_set = set(high_risk_transactions_std.index)

plt.figure(figsize=(20, 8))

# Define a function to update the text properties for labels and annotations
def update_venn_text_properties(venn_diagram, label_fontsize=14, num_fontsize=14):
    for text in venn_diagram.set_labels:
        if text:  # If the label is not None
            text.set_fontsize(label_fontsize)
    for text in venn_diagram.subset_labels:
        if text:  # If the subset label is not None
            text.set_fontsize(num_fontsize)

# Low Risk
plt.subplot(1, 3, 1)
venn_diagram = venn2([low_risk_transactions_set, low_risk_transactions_std_set], ('Model IQR', 'Model STD'), set_colors=('purple', 'green'))
venn_diagram.get_patch_by_id('11').set_color('orange')
update_venn_text_properties(venn_diagram, label_fontsize=12, num_fontsize=12)  # Adjust font sizes as needed
plt.title('Low Risk Transactions Overlap between Models', fontsize=14)

# Medium Risk
plt.subplot(1, 3, 2)
venn_diagram = venn2([medium_risk_transactions_set, medium_risk_transactions_std_set], ('Model IQR', 'Model STD'), set_colors=('purple', 'green'))
venn_diagram.get_patch_by_id('11').set_color('orange')
update_venn_text_properties(venn_diagram, label_fontsize=12, num_fontsize=12)  # Adjust font sizes as needed
plt.title('Medium Risk Transactions Overlap between Models', fontsize=14)

# High Risk
plt.subplot(1, 3, 3)
venn_diagram = venn2([high_risk_transactions_set, high_risk_transactions_std_set], ('Model IQR', 'Model STD'), set_colors=('purple', 'green'))
venn_diagram.get_patch_by_id('11').set_color('orange')
update_venn_text_properties(venn_diagram, label_fontsize=12, num_fontsize=12)  # Adjust font sizes as needed
plt.title('High Risk Transactions Overlap between Models', fontsize=14)

plt.tight_layout()
plt.show()

# %%
# Combine the sets for each model across all risk levels
model_iqr_combined_set = low_risk_transactions_set.union(medium_risk_transactions_set, high_risk_transactions_set)
model_std_combined_set = low_risk_transactions_std_set.union(medium_risk_transactions_std_set, high_risk_transactions_std_set)

# Create the Venn diagram for the overall flagged transactions
plt.figure(figsize=(4, 4))
venn_diagram= venn2([model_iqr_combined_set, model_std_combined_set], ('Model IQR', 'Model STD'), set_colors=('purple', 'green'))
venn_diagram.get_patch_by_id('11').set_color('orange')
plt.title('Flagged Transactions Overlap across all risk categories between Models IQR and STD')
plt.show()
